# %%
import requests
from bs4 import BeautifulSoup

# Define the URL of the webpage you want to scrape
url = "https://www.earthdata.nasa.gov/engage/open-data-services-and-software/api"

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content of the page using BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find the elements you want to scrape
    # For example, let's say you want to extract all the links on the page
    links = soup.find_all('a')
    
    # Loop through the links and print their text and href attributes
    for link in links:
        link_text = link.text
        link_href = link.get('href')
        print(f"Text: {link_text}, URL: {link_href}")
else:
    print("Failed to retrieve the webpage")
# Out:
# Text:
#       Skip to main content
#     , URL: #main-content
# Text:
#
#
# , URL: /
# Text: Get Started, URL: /learn/get-started
# Text: Find Data, URL: /learn/find-data
# Text: Use Data, URL: /learn/use-data
# Text:
#           Earthdata Search
#           , URL: https://search.earthdata.nasa.gov/
# Text:
#           Data Tools
#           , URL: /use-data/tools
# Text:
#           Data Recipes
#           , URL: /learn/data-recipes
# Text:
#           Worldview
#           , URL: /worldview
# Text:
#           Worldview Image of the Week
#           , URL: /worldview/worldview-image-archive
# Text:
#           Worldview Snapshots
#           , URL: /worldview/worldview-snapshots
# Text:
#           Global Imagery Browse Services (GIBS)
#           , URL: /eosdis/science-system-description/eosdis-components/gibs
# Text:
#           Common Metadata Repository (CMR)
#           , URL: /eosdis/science-system-description/eosdis-components/cmr
# Text:
#           Land, Atmosphere Near Real-Time Data (LANCE)
#           , URL: /learn/find-data/near-real-time
# Text:
#           Fire Information for Resource Management System (FIRMS)
#           , URL: /find-data/near-real-time/firms
# Text:
#           Active Fire Data
#           , URL: /learn/find-data/near-real-time/firms/active-fire-data
# Text:
#           Fire Email Alerts
#           , URL: https://firms.modaps.eosdis.nasa.gov/alerts/
# Text:
#           Fire Map (Global)
#           , URL: https://firms.modaps.eosdis.nasa.gov/map/
# Text:
#           Fire Map (US/Canada)
#           , URL: https://firms.modaps.eosdis.nasa.gov/usfs/map
# Text:
#           Topics
#           , URL: /topics
# Text: , URL: https://www.earthdata.nasa.gov/s3fs-public/2021-12/topics-nav-image.png?VersionId=QMAaSpRww7HoOsbxodDTFP9MPWmaR.3t
# Text:
#           Atmosphere
#           , URL: /topics/atmosphere
# Text:
#           Biosphere
#           , URL: /topics/biosphere
# Text:
#           Cryosphere
#           , URL: /topics/cryosphere
# Text:
#           Human Dimensions
#           , URL: /topics/human-dimensions
# Text:
#           Land Surface
#           , URL: /topics/land-surface
# Text:
#           Ocean
#           , URL: /topics/ocean
# Text:
#           Solid Earth
#           , URL: /topics/solid-earth
# Text:
#           Sun-Earth Interactions
#           , URL: /topics/sun-earth-interactions
# Text:
#           Terrestrial Hydrosphere
#           , URL: /topics/terrestrial-hydrosphere
# Text:
#
#
# , URL: /
# Text:
#           Learn
#           , URL: /learn
# Text: , URL: https://www.earthdata.nasa.gov/s3fs-public/2021-12/learn-nav-image.png?VersionId=aWb2AOrq0TWA1S.blcAnbck4BKhZxDMR
# Text:
#           Get Started
#           , URL: /learn/get-started
# Text:
#           Backgrounders
#           , URL: /learn/backgrounders
# Text:
#           Data Pathfinders
#           , URL: /learn/pathfinders
# Text:
#           Data Toolkits
#           , URL: /learn/toolkits
# Text:
#           Webinars and Tutorials
#           , URL: /learn/webinars-and-tutorials
# Text:
#           Articles
#           , URL: /learn/articles
# Text:
#           Data Chats
#           , URL: /learn/data-chat
# Text:
#           Data User Profiles
#           , URL: /learn/data-user-profiles
# Text:
#           Engage
#           , URL: /engage
# Text: , URL: https://www.earthdata.nasa.gov/s3fs-public/2021-12/engage-nav-image.png?VersionId=Iymn0s3WOLjfRuzdBAm8b14rgIvEoAxK
# Text:
#           Data Management Guidance
#           , URL: /engage/data-management-guidance
# Text:
#           Open Data, Services, and Software Policies
#           , URL: /engage/open-data-services-and-software
# Text:
#           Open Source Software Policy
#           , URL: /engage/open-data-services-and-software/esds-open-source-policy
# Text:
#           Application Programming Interfaces (APIs)
#           , URL: /engage/open-data-services-and-software/api
# Text:
#           Earthdata Code Collaborative (ECC)
#           , URL: /engage/ecc
# Text:
#           Standards
#           , URL: /engage/standards
# Text:
#           Data Standards and Requirements
#           , URL: /esdis/eso/standards-and-references
# Text:
#           Data Use Policy
#           , URL: /use-data/data-use-policy
# Text:
#           Data Citations and Acknowledgements
#           , URL: /use-data/data-citations-acknowledgements
# Text:
#           Adding New Data to EOSDIS
#           , URL: /engage/new-missions
# Text:
#           Public & Private Partnerships
#           , URL: /engage/esds-public-private-partnerships
# Text:
#           Memberships & Affiliations
#           , URL: /engage/memberships-and-affiliations
# Text:
#           About
#           , URL: /esds
# Text: , URL: https://www.earthdata.nasa.gov/s3fs-public/2021-12/about-nav-image.png?VersionId=KGfJpEh4f.srWVm42vPTk.ds3e_6SpAs
# Text:
#           Earth Science Data Systems (ESDS) Program
#           , URL: /esds
# Text:
#           ESDS Program Components
#           , URL: /esds/esds-program-components
# Text:
#           Commercial Smallsat Data Acquisition (CSDA) Program
#           , URL: /esds/csda
# Text:
#           Competitive Programs
#           , URL: /esds/competitive-programs
# Text:
#           Interagency Implementation and Advanced Concepts Team (IMPACT)
#           , URL: /esds/impact
# Text:
#           Earth Science Data and Information System (ESDIS) Project
#           , URL: /esdis
# Text:
#           Earth Observing System Data and Information System (EOSDIS)
#           , URL: /eosdis
# Text:
#           Distributed Active Archive Centers (DAAC)
#           , URL: /eosdis/daacs
# Text:
#           System Performance and Metrics
#           , URL: /eosdis/system-performance
# Text:
#           System Components
#           , URL: /eosdis/science-system-description/eosdis-components
# Text:
#           Data System Interfaces
#           , URL: /eosdis/data-system-interfaces
# Text: find data, URL: /learn/find-data
# Text: use data, URL: /learn/use-data
# Text: earthdata search, URL: https://search.earthdata.nasa.gov/
# Text: common metadata repository (cmr), URL: /eosdis/science-system-description/eosdis-components/cmr
# Text: data tools, URL: /use-data/tools
# Text: data recipes, URL: /learn/gis/data-recipes
# Text: worldview snapshots, URL: /worldview/worldview-snapshots
# Text: global imagery browse services (gibs), URL: /eosdis/science-system-description/eosdis-components/gibs
# Text: near real-time data, URL: /find-data/near-real-time
# Text: worldview, URL: /worldview
# Text: fire information for resource management system (firms) , URL: /find-data/near-real-time/firms
# Text: active fire data, URL: /find-data/near-real-time/firms/active-fire-data
# Text: fire email alerts, URL: https://firms.modaps.eosdis.nasa.gov/alerts/
# Text: fire map (global), URL: https://firms.modaps.eosdis.nasa.gov/
# Text: fire map (us/canada), URL: https://firms.modaps.eosdis.nasa.gov/usfs/web-services/
# Text: topics, URL: /topics
# Text: atmosphere, URL: /topics/atmosphere
# Text: biosphere, URL: /topics/biosphere
# Text: cryosphere, URL: /topics/cryosphere
# Text: human dimensions, URL: /topics/human-dimensions
# Text: land surface, URL: /topics/land-surface
# Text: ocean, URL: /topics/ocean
# Text: solid earth, URL: /topics/solid-earth
# Text: sun-earth interactions, URL: /topics/sun-earth-interactions
# Text: terrestrial hydrosphere, URL: /topics/terrestrial-hydrosphere
# Text: learn, URL: /learn
# Text: get started, URL: /learn/getting-started
# Text: backgrounders, URL: /learn/backgrounders
# Text: data pathfinders, URL: /learn/pathfinders
# Text: data toolkits, URL: /learn/toolkits
# Text: webinars and tutorials, URL: /learn/user-resources/webinars-and-tutorials
# Text: articles, URL: /learn/articles
# Text: data chats, URL: /learn/data-chat
# Text: data user profiles, URL: /learn/data-user-profiles
# Text: engage, URL: /engage
# Text: public & private partnerships, URL: /engage/esds-public-private-partnerships
# Text: memberships & affiliations, URL: /engage/memberships-and-affiliations
# Text: open data, services, and software policies , URL: /engage/open-data-services-and-software
# Text: open source software policy, URL: /engage/open-data-services-and-software/esds-open-source-policy
# Text: application programing interfaces (APIs), URL: /engage/open-data-services-and-software/api
# Text: earthdata code collaborative (ECC), URL: /engage/ecc
# Text: standards , URL: /engage/standards
# Text: data standards and requirements, URL: /esdis/eso/standards-and-references
# Text: data use policy, URL: /use-data/data-use-policy
# Text: data citations and acknowledgements, URL: /use-data/data-citations-acknowledgements
# Text: adding new data to eosdis, URL: /engage/new-missions
# Text: about, URL: /esds
# Text: earth science data systems (esds) program , URL: /esds
# Text: commercial smallsat data acquisition (csda) program, URL: /esds/csda
# Text: competitive programs, URL: /esds/competitive-programs
# Text: esds program components, URL: /esds/esds-program-components
# Text: interagency implementation and advanced concepts team (impact), URL: /esds/impact
# Text: earth science data and information system (esdis) project, URL: /esdis
# Text: earth observing system data and information system (eosdis) , URL: /eosdis
# Text: distributed active archive centers (daacs), URL: /eosdis/daacs
# Text: system performance and metrics, URL: /eosdis/system-performance
# Text: system components, URL: /eosdis/science-system-description/eosdis-components
# Text: data system interfaces, URL: /eosdis/data-system-interfaces
# Text: Earthdata, URL: /
# Text: Engage, URL: /engage
# Text: Open Data, Services, and Software Policies, URL: /engage/open-data-services-and-software
# Text: , URL: None
# Text: , URL: None
# Text: , URL: None
# Text: , URL: None
# Text: sending a request, URL: /contact
# Text: Common Metadata Repository (CMR) APIs, URL: #cmr
# Text: Distributed Active Archive Center (DAAC) APIs, URL: #daac
# Text: Earthdata Login APIs, URL: #edl
# Text: Earthdata Search APIs, URL: #edsc
# Text: Earthdata Tools APIs, URL: #tools
# Text: Global Imagery Browse Services (GIBS) APIs, URL: #gibs
# Text: Science Data Processing Software (SDPS) APIs, URL: #sdps
# Text: OPeNDAP APIs, URL: #opendap
# Text: Hyrax Data Server Installation and Configuration Guide, URL: #hyrax
# Text: NASA APIs, URL: #apis
# Text: , URL: None
# Text: Common Metadata Repository (CMR) APIs, URL: /collaborate/open-data-services-and-software/api/cmr-api
# Text: CMR, URL: /cmr
# Text: , URL: None
# Text: Distributed Active Archive Center (DAAC) APIs, URL: /collaborate/open-data-services-and-software/api/daac-apis
# Text: DAACs, URL: /daacs
# Text: , URL: None
# Text: Earthdata Login APIs, URL: /collaborate/open-data-services-and-software/api/earthdata-login-api
# Text: Earthdata Login, URL: /eosdis/science-system-description/eosdis-components/earthdata-login
# Text: , URL: None
# Text: Earthdata Search APIs, URL: /collaborate/open-data-services-and-software/api/earthdata-search-api
# Text: Earthdata Search, URL: https://search.earthdata.nasa.gov
# Text: , URL: None
# Text: Earthdata Tools APIs, URL: /collaborate/open-data-services-and-software/api/earthdata-tools-api
# Text: tools, URL: /tools
# Text: , URL: None
# Text: Global Imagery Browse Services (GIBS) APIs, URL: /collaborate/open-data-services-and-software/api/gibs-api
# Text: GIBS, URL: /gibs
# Text: , URL: None
# Text: Science Data Processing Software (SDPS) APIs, URL: /collaborate/open-data-services-and-software/api/sdps-api
# Text: NSIDC DAAC, URL: /nsidc
# Text: LP DAAC, URL: /lpdaac
# Text: ASDC, URL: /asdc
# Text: , URL: None
# Text: Open-source Project for a Network Data Access Protocol (OPeNDAP), URL: /collaborate/open-data-services-and-software/api/opendap
# Text: DAP, URL: http://www.opendap.org/pdf/ESE-RFC-004v1.1.pdf
# Text: OPeNDAP website, URL: http://www.opendap.org/
# Text: , URL: None
# Text: Hyrax Data Server Installation and Configuration Guide, URL: https://opendap.github.io/hyrax_guide/Master_Hyrax_Guide.html
# Text: NASA APIs, URL: https://api.nasa.gov/
# Text: Subscribe, URL: /subscribe
# Text: Contact Us, URL: /contact
# Text: Subscribe, URL: /subscribe
# Text: , URL: https://www.facebook.com/NASAEarthData
# Text:  , URL: https://twitter.com/NASAEarthData
# Text:  , URL: https://www.youtube.com/c/NASAEarthdata
# Text: Data, URL: /data
# Text: Find Data, URL: /data/find-data
# Text: Earthdata Search, URL: https://search.earthdata.nasa.gov/
# Text: Common Metadata Repository (CMR), URL: /eosdis/science-system-description/eosdis-components/cmr
# Text: International Directory Network (IDN), URL: https://idn.ceos.org/
# Text: Use Data, URL: /data/use-data
# Text: Data Tools, URL: /tools
# Text: Data Recipes, URL: /recipes
# Text: Worldview, URL: /worldview
# Text: Worldview Image of the Week, URL: /worldview/worldview-image-archive
# Text: Worldview Snapshots, URL: /snapshots
# Text: Global Imagery Browse Services (GIBS), URL: /gibs
# Text: Land, Atmosphere Near Real-Time Data (LANCE), URL: /learn/find-data/near-real-time
# Text: FIRMS, URL: /firms
# Text: Active Fire Data, URL: /learn/find-data/near-real-time/firms/active-fire-data
# Text: Fire Email Alerts, URL: https://firms.modaps.eosdis.nasa.gov/alerts/
# Text: Fire Map (Global), URL: https://firms.modaps.eosdis.nasa.gov/map/
# Text: Fire Map (US/Canada), URL: https://firms.modaps.eosdis.nasa.gov/usfs/map
# Text: Topics, URL: /topics
# Text: Atmosphere, URL: /topics/atmosphere
# Text: Biosphere, URL: /topics/biosphere
# Text: Cryosphere, URL: /topics/cryosphere
# Text: Human Dimensions, URL: /topics/human-dimensions
# Text: Land Surface, URL: /topics/land-surface
# Text: Ocean, URL: /topics/ocean
# Text: Solid Earth, URL: /topics/solid-earth
# Text: Sun-Earth Interactions, URL: /topics/sun-earth-interactions
# Text: Terrestrial Hydrosphere, URL: /topics/terrestrial-hydrosphere
# Text: Learn, URL: /learn
# Text: Get Started, URL: /learn/get-started
# Text: Backgrounders, URL: /learn/backgrounders
# Text: Data Pathfinders, URL: /learn/pathfinders
# Text: Data Toolkits, URL: /learn/toolkits
# Text: Webinars and Tutorials, URL: /webinars
# Text: Articles, URL: /learn/articles
# Text: Data User Profiles, URL: /learn/data-user-profiles
# Text: Data Chats, URL: /learn/data-chat
# Text: Engage, URL: /engage
# Text: Data Management Guidance for ESD-Funded Researchers, URL: /engage/data-management-guidance
# Text: Open Data, Services, and Software Policies, URL: /engage/open-data-services-and-software
# Text: Open Source Software Policy, URL: /engage/open-data-services-and-software/esds-open-source-policy
# Text: Earthdata Developer Resources & APIs, URL: /api
# Text: Earthdata Code Collaborative, URL: /ecc
# Text: Standards, URL: /esdis/eso/standards-and-references
# Text: Data Standards and Requirements, URL: /esdis/eso/standards-and-references
# Text: Data Use Policy, URL: /use-data/data-use-policy
# Text: Data Citations and Acknowledgements, URL: /use-data/data-citations-acknowledgements
# Text: Adding Data to EOSDIS, URL: /adding-data
# Text: Public/Private Partnerships, URL: /engage/esds-public-private-partnerships
# Text: Members and Affiliations, URL: /engage/memberships-and-affiliations
# Text: About, URL: /about
# Text: ESDS Program, URL: /esds
# Text: ESDS Program Components, URL: /esds/esds-program-components
# Text: Commercial Smallsat Data Acquisition (CSDA) Program, URL: /esds/csda
# Text: Competitive Programs, URL: /esds/competitive-programs
# Text: Interagency Implementation and Advanced Concepts Team (IMPACT), URL: /esds/impact
# Text: ESDIS Project, URL: /esdis
# Text: ESDIS Project Library, URL: https://doclib.eosdis.nasa.gov/ords/f?p=104
# Text: COMET (login required), URL: https://ops1-cm.ems.eosdis.nasa.gov/cm2/
# Text: EOSDIS, URL: /eosdis
# Text: DAACs, URL: /daacs
# Text: System Performance and Metrics, URL: /eosdis/system-performance
# Text: System Components, URL:
# Text: Data System Interfaces, URL: /eosdis/data-system-interfaces
# Text: Contact Us, URL: /contact
# Text: Earthdata Forum, URL: https://forum.earthdata.nasa.gov/
# Text: Community Forums, URL: /learn/earthdata-user-community-forums
# Text: Support, URL: /support
# Text: Web Privacy Policy, URL: https://www.nasa.gov/about/highlights/HP_Privacy.html
# Text: Data and Information Policy, URL: /engage/open-data-services-and-software/data-information-policy
# Text: Communications Policy, URL: https://www.nasa.gov/audience/formedia/features/communication_policy.html
# Text: Freedom of Information Act, URL: https://www.nasa.gov/FOIA/index.html
# Text: USA.gov, URL: https://www.usa.gov/
# Text: Sitemap, URL: /sitemap.xml

# %%
import requests
from bs4 import BeautifulSoup

# Define the URL of the webpage you want to scrape
url = "https://www.earthdata.nasa.gov/engage/open-data-services-and-software/api"

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content of the page using BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find all anchor (a) tags with href attributes
    links = soup.find_all('a', href=True)
    
    # Loop through the links and print their href attributes
    for link in links:
        link_href = link['href']
        print(link_href)
else:
    print("Failed to retrieve the webpage")
# Out:
# #main-content
# /
# /learn/get-started
# /learn/find-data
# /learn/use-data
# https://search.earthdata.nasa.gov/
# /use-data/tools
# /learn/data-recipes
# /worldview
# /worldview/worldview-image-archive
# /worldview/worldview-snapshots
# /eosdis/science-system-description/eosdis-components/gibs
# /eosdis/science-system-description/eosdis-components/cmr
# /learn/find-data/near-real-time
# /find-data/near-real-time/firms
# /learn/find-data/near-real-time/firms/active-fire-data
# https://firms.modaps.eosdis.nasa.gov/alerts/
# https://firms.modaps.eosdis.nasa.gov/map/
# https://firms.modaps.eosdis.nasa.gov/usfs/map
# /topics
# https://www.earthdata.nasa.gov/s3fs-public/2021-12/topics-nav-image.png?VersionId=QMAaSpRww7HoOsbxodDTFP9MPWmaR.3t
# /topics/atmosphere
# /topics/biosphere
# /topics/cryosphere
# /topics/human-dimensions
# /topics/land-surface
# /topics/ocean
# /topics/solid-earth
# /topics/sun-earth-interactions
# /topics/terrestrial-hydrosphere
# /
# /learn
# https://www.earthdata.nasa.gov/s3fs-public/2021-12/learn-nav-image.png?VersionId=aWb2AOrq0TWA1S.blcAnbck4BKhZxDMR
# /learn/get-started
# /learn/backgrounders
# /learn/pathfinders
# /learn/toolkits
# /learn/webinars-and-tutorials
# /learn/articles
# /learn/data-chat
# /learn/data-user-profiles
# /engage
# https://www.earthdata.nasa.gov/s3fs-public/2021-12/engage-nav-image.png?VersionId=Iymn0s3WOLjfRuzdBAm8b14rgIvEoAxK
# /engage/data-management-guidance
# /engage/open-data-services-and-software
# /engage/open-data-services-and-software/esds-open-source-policy
# /engage/open-data-services-and-software/api
# /engage/ecc
# /engage/standards
# /esdis/eso/standards-and-references
# /use-data/data-use-policy
# /use-data/data-citations-acknowledgements
# /engage/new-missions
# /engage/esds-public-private-partnerships
# /engage/memberships-and-affiliations
# /esds
# https://www.earthdata.nasa.gov/s3fs-public/2021-12/about-nav-image.png?VersionId=KGfJpEh4f.srWVm42vPTk.ds3e_6SpAs
# /esds
# /esds/esds-program-components
# /esds/csda
# /esds/competitive-programs
# /esds/impact
# /esdis
# /eosdis
# /eosdis/daacs
# /eosdis/system-performance
# /eosdis/science-system-description/eosdis-components
# /eosdis/data-system-interfaces
# /learn/find-data
# /learn/use-data
# https://search.earthdata.nasa.gov/
# /eosdis/science-system-description/eosdis-components/cmr
# /use-data/tools
# /learn/gis/data-recipes
# /worldview/worldview-snapshots
# /eosdis/science-system-description/eosdis-components/gibs
# /find-data/near-real-time
# /worldview
# /find-data/near-real-time/firms
# /find-data/near-real-time/firms/active-fire-data
# https://firms.modaps.eosdis.nasa.gov/alerts/
# https://firms.modaps.eosdis.nasa.gov/
# https://firms.modaps.eosdis.nasa.gov/usfs/web-services/
# /topics
# /topics/atmosphere
# /topics/biosphere
# /topics/cryosphere
# /topics/human-dimensions
# /topics/land-surface
# /topics/ocean
# /topics/solid-earth
# /topics/sun-earth-interactions
# /topics/terrestrial-hydrosphere
# /learn
# /learn/getting-started
# /learn/backgrounders
# /learn/pathfinders
# /learn/toolkits
# /learn/user-resources/webinars-and-tutorials
# /learn/articles
# /learn/data-chat
# /learn/data-user-profiles
# /engage
# /engage/esds-public-private-partnerships
# /engage/memberships-and-affiliations
# /engage/open-data-services-and-software
# /engage/open-data-services-and-software/esds-open-source-policy
# /engage/open-data-services-and-software/api
# /engage/ecc
# /engage/standards
# /esdis/eso/standards-and-references
# /use-data/data-use-policy
# /use-data/data-citations-acknowledgements
# /engage/new-missions
# /esds
# /esds
# /esds/csda
# /esds/competitive-programs
# /esds/esds-program-components
# /esds/impact
# /esdis
# /eosdis
# /eosdis/daacs
# /eosdis/system-performance
# /eosdis/science-system-description/eosdis-components
# /eosdis/data-system-interfaces
# /
# /engage
# /engage/open-data-services-and-software
# /contact
# #cmr
# #daac
# #edl
# #edsc
# #tools
# #gibs
# #sdps
# #opendap
# #hyrax
# #apis
# /collaborate/open-data-services-and-software/api/cmr-api
# /cmr
# /collaborate/open-data-services-and-software/api/daac-apis
# /daacs
# /collaborate/open-data-services-and-software/api/earthdata-login-api
# /eosdis/science-system-description/eosdis-components/earthdata-login
# /collaborate/open-data-services-and-software/api/earthdata-search-api
# https://search.earthdata.nasa.gov
# /collaborate/open-data-services-and-software/api/earthdata-tools-api
# /tools
# /collaborate/open-data-services-and-software/api/gibs-api
# /gibs
# /collaborate/open-data-services-and-software/api/sdps-api
# /nsidc
# /lpdaac
# /asdc
# /collaborate/open-data-services-and-software/api/opendap
# http://www.opendap.org/pdf/ESE-RFC-004v1.1.pdf
# http://www.opendap.org/
# https://opendap.github.io/hyrax_guide/Master_Hyrax_Guide.html
# https://api.nasa.gov/
# /subscribe
# /contact
# /subscribe
# https://www.facebook.com/NASAEarthData
# https://twitter.com/NASAEarthData
# https://www.youtube.com/c/NASAEarthdata
# /data
# /data/find-data
# https://search.earthdata.nasa.gov/
# /eosdis/science-system-description/eosdis-components/cmr
# https://idn.ceos.org/
# /data/use-data
# /tools
# /recipes
# /worldview
# /worldview/worldview-image-archive
# /snapshots
# /gibs
# /learn/find-data/near-real-time
# /firms
# /learn/find-data/near-real-time/firms/active-fire-data
# https://firms.modaps.eosdis.nasa.gov/alerts/
# https://firms.modaps.eosdis.nasa.gov/map/
# https://firms.modaps.eosdis.nasa.gov/usfs/map
# /topics
# /topics/atmosphere
# /topics/biosphere
# /topics/cryosphere
# /topics/human-dimensions
# /topics/land-surface
# /topics/ocean
# /topics/solid-earth
# /topics/sun-earth-interactions
# /topics/terrestrial-hydrosphere
# /learn
# /learn/get-started
# /learn/backgrounders
# /learn/pathfinders
# /learn/toolkits
# /webinars
# /learn/articles
# /learn/data-user-profiles
# /learn/data-chat
# /engage
# /engage/data-management-guidance
# /engage/open-data-services-and-software
# /engage/open-data-services-and-software/esds-open-source-policy
# /api
# /ecc
# /esdis/eso/standards-and-references
# /esdis/eso/standards-and-references
# /use-data/data-use-policy
# /use-data/data-citations-acknowledgements
# /adding-data
# /engage/esds-public-private-partnerships
# /engage/memberships-and-affiliations
# /about
# /esds
# /esds/esds-program-components
# /esds/csda
# /esds/competitive-programs
# /esds/impact
# /esdis
# https://doclib.eosdis.nasa.gov/ords/f?p=104
# https://ops1-cm.ems.eosdis.nasa.gov/cm2/
# /eosdis
# /daacs
# /eosdis/system-performance
#
# /eosdis/data-system-interfaces
# /contact
# https://forum.earthdata.nasa.gov/
# /learn/earthdata-user-community-forums
# /support
# https://www.nasa.gov/about/highlights/HP_Privacy.html
# /engage/open-data-services-and-software/data-information-policy
# https://www.nasa.gov/audience/formedia/features/communication_policy.html
# https://www.nasa.gov/FOIA/index.html
# https://www.usa.gov/
# /sitemap.xml

# %%
import requests
from bs4 import BeautifulSoup
import csv

# Define the URL of the webpage you want to scrape
url = "https://www.earthdata.nasa.gov/engage/open-data-services-and-software/api"

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content of the page using BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find all anchor (a) tags with href attributes
    links = soup.find_all('a', href=True)
    
    # Create a list to store the links
    link_list = []
    
    # Loop through the links and add their href attributes to the list
    for link in links:
        link_href = link['href']
        link_list.append(link_href)
    
    # Define the CSV file name
    csv_filename = "nasa_earth_data_links.csv"
    
    # Write the links to a CSV file
    with open(csv_filename, 'w', newline='') as csv_file:
        writer = csv.writer(csv_file)
        writer.writerow(['Link'])  # Write a header row
        for link in link_list:
            writer.writerow([link])
    
    print(f"Scraped links saved to {csv_filename}")
else:
    print("Failed to retrieve the webpage")
# Out:
# Scraped links saved to nasa_earth_data_links.csv

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Define the URL of the webpage you want to scrape
url = "https://www.earthdata.nasa.gov/engage/open-data-services-and-software/api"

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content of the page using BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find all anchor (a) tags with href attributes
    links = soup.find_all('a', href=True)
    
    # Create a list to store the links
    link_list = []
    
    # Loop through the links and add their href attributes to the list
    for link in links:
        link_href = link['href']
        link_list.append(link_href)
    
    # Create a DataFrame from the list of links
    df = pd.DataFrame({'Link': link_list})
    
    # Print the first few rows of the DataFrame
    print(df.head())
else:
    print("Failed to retrieve the webpage")
# Out:
#                  Link
# 0       #main-content
# 1                   /
# 2  /learn/get-started
# 3    /learn/find-data
# 4     /learn/use-data

# %%
# Make a request to https://codedamn-classrooms.github.io/webscraper-python-codedamn-classroom-website/
# Store the result in 'res' variable
res = requests.get(
    'https://www.earthdata.nasa.gov/engage/open-data-services-and-software/api ')
txt = res.text
status = res.status_code

print(txt, status)
# print the result
# Out:
# <!DOCTYPE html>
# <html lang="en" dir="ltr" prefix="content: http://purl.org/rss/1.0/modules/content/  dc: http://purl.org/dc/terms/  foaf: http://xmlns.com/foaf/0.1/  og: http://ogp.me/ns#  rdfs: http://www.w3.org/2000/01/rdf-schema#  schema: http://schema.org/  sioc: http://rdfs.org/sioc/ns#  sioct: http://rdfs.org/sioc/types#  skos: http://www.w3.org/2004/02/skos/core#  xsd: http://www.w3.org/2001/XMLSchema# ">
#   <head>
#     <meta charset="utf-8" />
# <link rel="canonical" href="https://www.earthdata.nasa.gov/" />
# <link rel="shortlink" href="https://www.earthdata.nasa.gov/" />
# <meta name="news_keywords" content="NASA, Earth, Space, Science, Satellite, Satellite Photo, DAAC, ," />
# <link rel="image_src" href="https://www.earthdata.nasa.gov/s3fs-public/imported/ed-default-thumbnail.png" />
# <meta name="rating" content="general" />
# <meta name="description" content="Earthdata is the home for full and open access to NASA&#039;s Earth science data collections, accelerating scientific advancement for societal benefit." />
# <meta name="keywords" content="NASA, Earth Science Data Systems, Earthdata, Earth, Data, Science, Space, Atmosphere, Environment, Satellites, Missions" />
# <meta name="dcterms.title" content="Page not found | Earthdata" />
# <meta name="dcterms.creator" content="Earth Science Data Systems, NASA" />
# <meta name="dcterms.subject" content="Earth Science" />
# <meta name="dcterms.description" content="Earthdata is the home for full and open access to NASA&#039;s Earth science data collections, accelerating scientific advancement for societal benefit." />
# <meta name="dcterms.publisher" content="Earth Science Data Systems, NASA" />
# <meta name="dcterms.contributor" content="Earth Science Data Systems, NASA" />
# <meta property="og:site_name" content="Earthdata" />
# <meta property="og:url" content="https://www.earthdata.nasa.gov/engage/open-data-services-and-software/api%2520" />
# <meta property="og:title" content="Page not found | Earthdata" />
# <meta property="og:description" content="Earthdata is the home for full and open access to NASA&#039;s Earth science data collections, accelerating scientific advancement for societal benefit." />
# <meta property="og:image" content="https://www.earthdata.nasa.gov/s3fs-public/imported/ed-default-thumbnail.png" />
# <meta property="og:image:alt" content="This is the default thumbnail image for NASA Earthdata." />
# <meta name="twitter:card" content="summary" />
# <meta name="twitter:site" content="@NASAEarthData" />
# <meta name="twitter:description" content="Earthdata is the home for full and open access to NASA&#039;s Earth science data collections, accelerating scientific advancement for societal benefit." />
# <meta name="twitter:title" content="Page not found | Earthdata" />
# <meta name="twitter:url" content="https://www.earthdata.nasa.gov/engage/open-data-services-and-software/api%2520" />
# <meta name="twitter:image:alt" content="This is the default thumbnail image for NASA Earthdata." />
# <meta name="twitter:image" content="https://www.earthdata.nasa.gov/s3fs-public/imported/ed-default-thumbnail.png" />
# <meta name="Generator" content="Drupal 9 (https://www.drupal.org)" />
# <meta name="MobileOptimized" content="width" />
# <meta name="HandheldFriendly" content="true" />
# <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no" />
# <script type="application/ld+json">{
#     "@context": "https://schema.org",
#     "@graph": [
#         {
#             "@type": "WebSite",
#             "@id": "https://earthdata.nasa.gov/",
#             "name": "Earthdata",
#             "url": "https://earthdata.nasa.gov/",
#             "potentialAction": {
#                 "@type": "SearchAction",
#                 "target": {
#                     "@type": "EntryPoint",
#                     "urlTemplate": "https://earthdata.nasa.gov/search?keys={search_term_string}",
#                     "inLanguage": "en-US"
#                 },
#                 "result": {
#                     "@type": "GovernmentOrganization",
#                     "@id": "https://earthdata.nasa.gov/",
#                     "name": [
#                         "Earth Science Data Systems",
#                         "NASA"
#                     ],
#                     "url": "https://earthdata.nasa.gov/"
#                 },
#                 "query": "https://www.earthdata.nasa.gov/search?keys={search_term_string}",
#                 "query-input": "required name=search_term_string"
#             },
#             "publisher": {
#                 "@type": "GovernmentOffice",
#                 "@id": "https://earthdata.nasa.gov/",
#                 "name": [
#                     "Earth Science Data Systems",
#                     "NASA"
#                 ],
#                 "url": "https://earthdata.nasa.gov/",
#                 "logo": {
#                     "@type": "ImageObject",
#                     "representativeOfPage": "True",
#                     "url": "https://www.earthdata.nasa.gov/s3fs-public/earthdata-oaos-logo-hover.png",
#                     "width": "265px",
#                     "height": "50px"
#                 }
#             },
#             "inLanguage": "en-US"
#         }
#     ]
# }</script>
# <meta http-equiv="x-ua-compatible" content="ie=edge" />
# <script type="application/ld+json">{
#           "@context": "https://schema.org",
#           "@type": "BreadcrumbList",
#           "itemListElement": [{
#             "@type": "ListItem",
#             "position": "1",
#             "name": "Earthdata",
#             "item": "https://www.earthdata.nasa.gov/"
#           },{
#               "@type": "ListItem",
#               "position": "2",
#               "name": "System"
#             },{
#               "@type": "ListItem",
#               "position": "3",
#               "name": "Page Not Found"
#             }]}</script>
# <link rel="icon" href="/sites/default/files/nasa-meatball.png" type="image/png" />
# <script>window.a2a_config=window.a2a_config||{};a2a_config.callbacks=[];a2a_config.overlays=[];a2a_config.templates={};a2a_config.icon_color = "#22b463";</script>
#
#     <title>Page not found | Earthdata</title>
#     <link rel="stylesheet" media="all" href="/s3fs-public/css/css_yeMRJFs4pJyswI72QASGfSs2mTXW17BvcXjW4NOjEFU.css?VersionId=WH3NDYvACH67wQCirJlZAGtIurAvuruq" />
# <link rel="stylesheet" media="all" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.3.0/css/font-awesome.min.css" />
# <link rel="stylesheet" media="all" href="/s3fs-public/css/css_XtSvlgbQYjcDoeApsmyGPrq_13D4jgFxUbmjux3Cnrs.css?VersionId=HsTnZoCqE8TsBpA8uAEcp79Dwch.2_Q0" />
# <link rel="stylesheet" media="all" href="/s3fs-public/css/css_O1xqJyUcqlIHj5lamlINh3kOdjGjxZzm9LoUTcVtbXo.css?VersionId=iD6uPtlWcrgRP3IiJzjZ32YQK1gvZhvQ" />
# <link rel="stylesheet" media="all" href="//use.fontawesome.com/releases/v5.13.0/css/all.css" />
# <link rel="stylesheet" media="all" href="/s3fs-public/css/css_Z0EWytWlrXjitsepirFcFc9l-ewB8O2kdxzYGsz4bDQ.css?VersionId=o3d.vtX.fZLc1.6NpJwJv4JhTaB6zT2d" />
# <link rel="stylesheet" media="all" href="//fonts.googleapis.com/css2?family=Open+Sans:ital,wght@0,300;0,400;0,600;0,700;0,800;1,300;1,400;1,600;1,700;1,800&amp;display=swap" />
# <link rel="stylesheet" media="all" href="/s3fs-public/css/css_dW8MKPHWLPZui6ms4gBw7I9kyIWmqXhlvGM3oU8Sw3A.css?VersionId=eMqn.y2gF5VeaJXHxiPcc6lyZYH84u1t" />
#
#     <script type="application/json" data-drupal-selector="drupal-settings-json">{"path":{"baseUrl":"\/","scriptPath":null,"pathPrefix":"","currentPath":"","currentPathIsAdmin":false,"isFront":false,"currentLanguage":"en"},"pluralDelimiter":"\u0003","suppressDeprecationErrors":true,"data":{"extlink":{"extTarget":false,"extTargetNoOverride":false,"extNofollow":false,"extNoreferrer":true,"extFollowNoOverride":false,"extClass":"ext","extLabel":"(link is external)","extImgClass":false,"extSubdomains":true,"extExclude":"","extInclude":"","extCssExclude":".node--type-job-opening .field--name-field-job-url","extCssExplicit":"","extAlert":true,"extAlertText":"This link will take you to an external web site. We are not responsible for their content.","mailtoClass":"mailto","mailtoLabel":"(link sends email)","extUseFontAwesome":false,"extIconPlacement":"append","extFaLinkClasses":"fa fa-external-link","extFaMailtoClasses":"fa fa-envelope-o","whitelistedDomains":[".*\\earthdata.nasa.gov","firms.modaps.eosdis.nasa.gov","d10a3v3te7tlzl.cloudfront.net","d2cw1xlrxl8h8g.cloudfront.net","d371hv6zcxz9vm.cloudfront.net",".*\\cloudfront.net","nasaenterprise.webex.com"]}},"ckeditorAccordion":{"accordionStyle":{"collapseAll":1,"keepRowsOpen":1}},"collapsiblock":{"active_pages":false,"slide_speed":200,"cookie_lifetime":null},"TBMegaMenu":{"TBElementsCounter":{"column":29},"theme":"earthdata"},"colorbox":{"opacity":"0.85","current":"{current} of {total}","previous":"\u00ab Prev","next":"Next \u00bb","close":"Close","maxWidth":"98%","maxHeight":"98%","fixed":true,"mobiledetect":false,"mobiledevicewidth":"480px"},"user":{"uid":0,"permissionsHash":"9f96380f838406ed8b8f43f34118025525e1eacaed9bcd1327470113de0d27cb"}}</script>
# <script src="/s3fs-public/js/js_OjTLiimmGzO8fQT0OdX2VuzljtqLW1C6POMpz9y3EBU.js?VersionId=Smji5H4cWx8JOXNcGtRKtch7l3U8o0mG"></script>
# <script src="//www.googletagmanager.com/gtag/js?id=GTM-WNP7MLF" async></script>
# <script src="//script.crazyegg.com/pages/scripts/0013/2090.js" async></script>
# <script src="//dap.digitalgov.gov/Universal-Federated-Analytics-Min.js?agency=NASA&amp;subagency=GSFC&amp;dclink=true" id="_fed_an_ua_tag"></script>
#
#       <meta name="orgcode" content="613">
#       <meta name="rno" content="Kevin Murphy">
#       <meta name="content-owner" content="Kevin Ward">
#       <meta name="webmaster" content="Goran Halusa">
#       <meta name="description" content="The Earth Observing System Data and Information System
#        is a key core capability in NASA’s Earth Science Data Systems Program. It provides end-to-end
#        capabilities for managing NASA’s Earth science data from various sources—satellites, aircraft,
#        field measurements, and various other programs.">
#   </head>
#   <body class="layout-no-sidebars path-engage">
#               <!-- Google Tag Manager (noscript) -->
#       <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-WNP7MLF" height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
#       <!-- End Google Tag Manager (noscript) -->
#         <a href="#main-content" class="visually-hidden focusable skip-link">
#       Skip to main content
#     </a>
#
#       <div class="dialog-off-canvas-main-canvas" data-off-canvas-main-canvas>
#     <div id="page-wrapper">
#   <div id="page">
#     <header id="header" class="header" role="banner" aria-label="Site header">
#                       <nav class="navbar navbar-dark navbar-expand-lg" id="navbar-main">
#                     <div class="container">
#                               <div id="home" class="mb-auto">
#     <a href="/" title="Home" rel="home" class="navbar-brand">
#       <img class="logo" src="/sites/default/files/earthdata-oaos-logo.png" alt="Earthdata logo" />
#       <img class="logo-color" src="/sites/default/files/earthdata-oaos-logo-hover.png" alt="Earthdata logo" />
#
#     </a>
#     </div>
#
#
#                           <button class="navbar-toggler navbar-toggler-right" type="button" data-toggle="collapse" data-target="#CollapsingNavbar" aria-controls="CollapsingNavbar" aria-expanded="false" aria-label="Toggle navigation"><span class="navbar-toggler-icon"></span></button>
#               <div class="collapse navbar-collapse justify-content-end" id="CollapsingNavbar">
#                   <div id="block-mainnavigation" data-block-plugin-id="tb_megamenu_menu_block:main" class="block block-tb-megamenu block-tb-megamenu-menu-blockmain">
#
#
#       <div class="content">
#       <div  class="tb-megamenu tb-megamenu-main" role="navigation" aria-label="Main navigation">
#       <button data-target=".nav-collapse" data-toggle="collapse" class="btn btn-navbar tb-megamenu-button d-block d-sm-block d-md-block d-lg-none" type="button">
#       <i class="fa fa-reorder"></i>
#     </button>
#     <div class="nav-collapse  always-show">
#     <ul  class="tb-megamenu-nav nav level-0 items-5 d-none d-sm-none d-md-none d-lg-block" role="list" >
#
#
# <li  class="tb-megamenu-item level-1 mega mega-align-justify dropdown" data-id="menu_link_content:9b027c3e-2abd-4d9e-844c-70b6c9475cd8" data-level="1" data-type="menu_item" data-class="" data-xicon="" data-caption="" data-alignsub="justify" data-group="0" data-hidewcol="0" data-hidesub="0" data-label="" aria-level="1" >
#       <span class="dropdown-toggle tb-megamenu-no-link" aria-expanded="false" tabindex="0">
#           Data
#           </span>
#   <div  class="tb-megamenu-submenu dropdown-menu mega-dropdown-menu nav-child fullwidth" data-class="" data-pixelsorfullwidth="1" data-width="" data-fullwidthtarget="#navbar-main" fullwidth-target="#navbar-main" role="list">
#   <div class="mega-dropdown-inner container">
#           <div  class="tb-megamenu-row row-fluid">
#         <div  data-showblocktitle="1" class="tb-megamenu-column span4 mega-col-nav" data-class="" data-width="4" data-hidewcol="0" id="tb-megamenu-column-1">
#   <div class="tb-megamenu-column-inner mega-inner clearfix">
#                  <div  class="tb-block tb-megamenu-block" data-type="block" data-block="navdatadescription">
#     <div class="block-inner">
#       <div id="block-block-contentaf9eda4c-f62c-41b2-b949-2941b9ce389f" data-block-plugin-id="block_content:af9eda4c-f62c-41b2-b949-2941b9ce389f" class="block block-block-content block-block-contentaf9eda4c-f62c-41b2-b949-2941b9ce389f">
#
#
#       <div class="content">
#
#             <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item"><h2>Data</h2>
#
# <p>Find and use NASA Earth science data fully, openly, and without restrictions.</p>
#
# <div class="d-grid gap-2"><a class="btn btn-green" href="/learn/get-started" role="button">Get Started</a> <a class="btn btn-green" href="/learn/find-data" role="button">Find Data</a> <a class="btn btn-green" href="/learn/use-data" role="button">Use Data</a></div>
# </div>
#
#     </div>
#   </div>
#
#     </div>
#   </div>
#
#       </div>
# </div>
#
#         <div  class="tb-megamenu-column span4 mega-col-nav" data-class="" data-width="4" data-hidewcol="" id="tb-megamenu-column-2">
#   <div class="tb-megamenu-column-inner mega-inner clearfix">
#                <ul  class="tb-megamenu-subnav mega-nav level-1 items-8" role="list">
#
#
# <li  class="tb-megamenu-item level-2 mega" data-id="menu_link_content:e9f37aea-89bc-4a58-b603-01268d06a303" data-level="2" data-type="menu_item" data-class="" data-xicon="" data-caption="" data-alignsub="" data-group="0" data-hidewcol="0" data-hidesub="0" data-label="" aria-level="2" >
#       <a href="https://search.earthdata.nasa.gov/" >
#           Earthdata Search
#           </a>
#
# </li>
#
#
#
# <li  class="tb-megamenu-item level-2 mega" data-id="menu_link_content:6d3b9c4c-712d-4f7d-978d-7b92fad467ee" data-level="2" data-type="menu_item" data-class="" data-xicon="" data-caption="" data-alignsub="" data-group="0" data-hidewcol="0" data-hidesub="0" data-label="" aria-level="2" >
#       <a href="/use-data/tools" >
#           Data Tools
#           </a>
#
# </li>
#
#
#
# <li  class="tb-megamenu-item level-2 mega" data-id="menu_link_content:43eee3c7-52ac-43c8-b3de-2295344a1321" data-level="2" data-type="menu_item" data-class="" data-xicon="" data-caption="" data-alignsub="" data-group="0" data-hidewcol="0" data-hidesub="0" data-label="" aria-level="2" >
#       <a href="/learn/data-recipes" >
#           Data Recipes
#           </a>
#
# </li>
#
#
#
# <li  class="tb-megamenu-item level-2 mega" data-id="menu_link_content:291c2b38-38a7-432e-810c-3b4b8ba8a3fb" data-level="2" data-type="menu_item" data-class="" data-xicon="" data-caption="" data-alignsub="" data-group="0" data-hidewcol="0" data-hidesub="0" data-label="" aria-level="2" >
#       <a href="/worldview" >
#           Worldview
#           </a>
#
# </li>
#
#
#
# <li  class="tb-megamenu-item level-2 mega" data-id="menu_link_content:626c86cd-d7e7-433c-8424-2b38cb479214" data-level="2" data-type="menu_item" data-class="" data-xicon="" data-caption="" data-alignsub="" data-group="0" data-hidewcol="0" data-hidesub="0" data-label="" aria-level="2" >
#       <a href="/worldview/worldview-image-archive" >
#           Worldview Image of the Week
#           </a>
#
# </li>
#
#
#
# <li  class="tb-megamenu-item level-2 mega" data-id="menu_link_content:dfd8d16b-2993-44fe-8a60-5966edce70d2" data-level="2" data-type="menu_item" data-class="" data-xicon="" data-caption="" data-alignsub="" data-group="0" data-hidewcol="0" data-hidesub="0" data-label="" aria-level="2" >
#       <a href="/worldview/worldview-snapshots" >
#           Worldview Snapshots
#           </a>
#
# </li>
#
#
#
# <li  class="tb-megamenu-item level-2 mega" data-id="menu_link_content:c33f8206-4303-44f2-ada7-52c6bf45f6d5" data-level="2" data-type="menu_item" data-class="" data-xicon="" data-caption="" data-alignsub="" data-group="0" data-hidewcol="0" data-hidesub="0" data-label="" aria-level="2" >
#       <a href="/eosdis/science-system-description/eosdis-components/gibs" >
#           Global Imagery Browse Services (GIBS)
#           </a>
#
# </li>
#
#
#
# <li  class="tb-megamenu-item level-2 mega" data-id="menu_link_content:a16f897a-012e-4201-bb02-958aae8686d6" data-level="2" data-type="menu_item" data-class="" data-xicon="" data-caption="" data-alignsub="" data-group="0" data-hidewcol="0" data-hidesub="0" data-label="" aria-level="2" >
#       <a href="/eosdis/science-system-description/eosdis-components/cmr" >
#           Common Metadata Repository (CMR)
#           </a>
#
# </li>
#
#   </ul>
#
#       </div>
# </div>
#
#         <div  class="tb-megamenu-column span4 mega-col-nav" data-class="" data-width="4" data-hidewcol="" id="tb-megamenu-column-3">
#   <div class="tb-megamenu-column-inner mega-inner clearfix">
#                <ul  class="tb-megamenu-subnav mega-nav level-1 items-2" role="list">
#
#
# <li  class="tb-megamenu-item level-2 mega" data-id="menu_link_content:23a0d1f5-b0d7-4b70-ad2b-d4368987fea8" data-level="2" data-type="menu_item" data-class="" data-xicon="" data-caption="" data-alignsub="" data-group="0" data-hidewcol="0" data-hidesub="0" data-label="" aria-level="2" >
#       <a href="/learn/find-data/near-real-time" >
#           Land, Atmosphere Near Real-Time Data (LANCE)
#           </a>
#
# </li>
#
#
#
# <li  class="tb-megamenu-item level-2 mega mega-group" data-id="menu_link_content:4fe14958-1f3e-474a-9afd-2e6c9d389514" data-level="2" data-type="menu_item" data-class="" data-xicon="" data-caption="" data-alignsub="" data-group="1" data-hidewcol="0" data-hidesub="0" data-label="" aria-level="2" >
#       <a href="/find-data/near-real-time/firms"  class="mega-group-title" aria-expanded="false">
#           Fire Information for Resource Management System (FIRMS)
#           </a>
#   <div  class="tb-megamenu-submenu mega-group-ct nav-child" data-class="" data-pixelsorfullwidth="0" data-width="" data-fullwidthtarget="" role="list">
#   <div class="mega-dropdown-inner container">
#           <div  class="tb-megamenu-row row-fluid">
#         <div  class="tb-megamenu-column mega-col-nav col-md-3 col-lg-3 col-xl-12" data-class="" data-hidewcol="0" id="tb-megamenu-column-4">
#   <div class="tb-megamenu-column-inner mega-inner clearfix">
#                <ul  class="tb-megamenu-subnav mega-nav level-2 items-4" role="list">
#
#
# <li  class="tb-megamenu-item level-3 mega" data-id="menu_link_content:b38d6b2b-71b6-4c88-8743-7f6de3404dd0" data-level="3" data-type="menu_item" data-class="" data-xicon="" data-caption="" data-alignsub="" data-group="0" data-hidewcol="0" data-hidesub="0" data-label="" aria-level="3" >
#       <a href="/learn/find-data/near-real-time/firms/active-fire-data" >
#           Active Fire Data
#           </a>
#
# </li>
#
#
#
# <li  class="tb-megamenu-item level-3 mega" data-id="menu_link_content:88fc7e06-162c-4030-8ad1-b680a772f185" data-level="3" data-type="menu_item" data-class="" data-xicon="" data-caption="" data-alignsub="" data-group="0" data-hidewcol="0" data-hidesub="0" data-label="" aria-level="3" >
#       <a href="https://firms.modaps.eosdis.nasa.gov/alerts/" >
#           Fire Email Alerts
#           </a>
#
# </li>
#
#
#
# <li  class="tb-megamenu-item level-3 mega" data-id="menu_link_content:3639fc7e-4c72-458f-befc-74deb1f8bef7" data-level="3" data-type="menu_item" data-class="" data-xicon="" data-caption="" data-alignsub="" data-group="0" data-hidewcol="0" data-hidesub="0" data-label="" aria-level="3" >
#       <a href="https://firms.modaps.eosdis.nasa.gov/map/" >
#           Fire Map (Global)
#           </a>
#
# </li>
#
#
#
# <li  class="tb-megamenu-item level-3 mega" data-id="menu_link_content:bb05528b-af0e-4788-a9f7-73f136c0fdf6" data-level="3" data-type="menu_item" data-class="" data-xicon="" data-caption="" data-alignsub="" data-group="0" data-hidewcol="0" data-hidesub="0" data-label="" aria-level="3" >
#       <a href="https://firms.modaps.eosdis.nasa.gov/usfs/map" >
#           Fire Map (US/Canada)
#           </a>
#
# </li>
#
#   </ul>
#
#       </div>
# </div>
#
#   </div>
#
#       </div>
# </div>
#
# </li>
#
#   </ul>
#
#       </div>
# </div>
#
#   </div>
#
#       </div>
# </div>
#
# </li>
#
#
#
# <li  class="tb-megamenu-item level-1 mega mega-align-justify dropdown" data-id="menu_link_content:91363c52-b5bb-4d10-8d66-476993fd3a28" data-level="1" data-type="menu_item" data-class="" data-xicon="" data-caption="" data-alignsub="justify" data-group="0" data-hidewcol="0" data-hidesub="0" data-label="" aria-level="1" >
#       <a href="/topics"  class="dropdown-toggle" aria-expanded="false">
#           Topics
#           </a>
#   <div  class="tb-megamenu-submenu dropdown-menu mega-dropdown-menu nav-child fullwidth" data-class="" data-pixelsorfullwidth="1" data-width="" data-fullwidthtarget="#navbar-main" fullwidth-target="#navbar-main" role="list">
#   <div class="mega-dropdown-inner container">
#           <div  class="tb-megamenu-row row-fluid">
#         <div  data-showblocktitle="1" class="tb-megamenu-column span4 mega-col-nav" data-class="" data-width="4" data-hidewcol="0" id="tb-megamenu-column-5">
#   <div class="tb-megamenu-column-inner mega-inner clearfix">
#                  <div  class="tb-block tb-megamenu-block" data-type="block" data-block="navtopicsdescription">
#     <div class="block-inner">
#       <div id="block-block-content935b09e7-c611-4c7d-b2c0-6995a5918e17" data-block-plugin-id="block_content:935b09e7-c611-4c7d-b2c0-6995a5918e17" class="block block-block-content block-block-content935b09e7-c611-4c7d-b2c0-6995a5918e17">
#
#
#       <div class="content">
#
#             <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item"><h2>Topics</h2>
#
# <p>Recognizing the connections between interdependent Earth systems is critical for understanding the world in which we live.</p>
#
# <div class="align-left">
#
#
#   <div class="field field--name-field-media-image field--type-image field--label-visually_hidden">
#     <div class="field__label visually-hidden">Image</div>
#               <div class="field__item">
# <a href="https://www.earthdata.nasa.gov/s3fs-public/2021-12/topics-nav-image.png?VersionId=QMAaSpRww7HoOsbxodDTFP9MPWmaR.3t" aria-controls="colorbox" aria-label="{&quot;title&quot;:&quot;Earthdata Topics&quot;,&quot;alt&quot;:&quot;Topics navigation graphic - a globe and magnifying glass.&quot;}" role="button" title="" data-colorbox-gallery="gallery-image-44816-aI68BhbglbM" class="colorbox" data-cbox-img-attrs="{&quot;title&quot;:&quot;Earthdata Topics&quot;,&quot;alt&quot;:&quot;Topics navigation graphic - a globe and magnifying glass.&quot;}"><img src="/s3fs-public/2021-12/topics-nav-image.png?VersionId=QMAaSpRww7HoOsbxodDTFP9MPWmaR.3t" width="350" height="183" alt="Topics navigation graphic - a globe and magnifying glass." title="Earthdata Topics" loading="lazy" typeof="foaf:Image" /></a>
# </div>
#           </div>
#
# </div>
# </div>
#
#     </div>
#   </div>
#
#     </div>
#   </div>
#
#       </div>
# </div>
#
#         <div  class="tb-megamenu-column span4 mega-col-nav" data-class="" data-width="4" data-hidewcol="" id="tb-megamenu-column-6">
#   <div class="tb-megamenu-column-inner mega-inner clearfix">
#                <ul  class="tb-megamenu-subnav mega-nav level-1 items-9" role="list">
#
#
# <li  class="tb-megamenu-item level-2 mega dropdown-submenu" data-id="menu_link_content:5331f5e2-7f2e-4224-b3b3-0a2592f5fe19" data-level="2" data-type="menu_item" data-class="" data-xicon="" data-caption="" data-alignsub="" data-group="0" data-hidewcol="0" data-hidesub="0" data-label="" aria-level="2" >
#       <a href="/topics/atmosphere"  class="dropdown-toggle" aria-expanded="false">
#           Atmosphere
#           </a>
#   <div  class="tb-megamenu-submenu dropdown-menu mega-dropdown-menu nav-child" data-class="" data-pixelsorfullwidth="0" data-width="" data-fullwidthtarget="" role="list">
#   <div class="mega-dropdown-inner container">
#           <div  class="tb-megamenu-row row-fluid">
#         <div  data-showblocktitle="1" class="tb-megamenu-column mega-col-nav col-md-3 col-lg-3 col-xl-12" data-class="" data-hidewcol="" id="tb-megamenu-column-7">
#   <div class="tb-megamenu-column-inner mega-inner clearfix">
#                  <div  class="tb-block tb-megamenu-block" data-type="block" data-block="navtopicatmosphere">
#     <div class="block-inner">
#       <div id="block-block-contentdbbd2bf0-3ea1-498c-a4a4-cce81d392772" data-block-plugin-id="block_content:dbbd2bf0-3ea1-498c-a4a4-cce81d392772" class="block block-block-content block-block-contentdbbd2bf0-3ea1-498c-a4a4-cce81d392772">
#
#
#       <div class="content">
#
#             <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item"><h3 class="text-align-left">Atmosphere</h3>
#
# <p class="text-align-left">The atmosphere is a gaseous envelope surrounding and protecting our planet from the intense radiation of the Sun and serves as a key interface between the terrestrial and ocean cycles.</p>
#
# <p class="mt-2" style="text-align:center"><img alt="Atmosphere icon" src="/sites/default/files/2021-08/atmosphere-icon.png" width="150" /></p>
# </div>
#
#     </div>
#   </div>
#
#     </div>
#   </div>
#
#       </div>
# </div>
#
#   </div>
#
#       </div>
# </div>
#
# </li>
#
#
#
# <li  class="tb-megamenu-item level-2 mega dropdown-submenu" data-id="menu_link_content:1cd33c55-e90a-4395-a388-36282bc05335" data-level="2" data-type="menu_item" data-class="" data-xicon="" data-caption="" data-alignsub="" data-group="0" data-hidewcol="0" data-hidesub="0" data-label="" aria-level="2" >
#       <a href="/topics/biosphere"  class="dropdown-toggle" aria-expanded="false">
#           Biosphere
#           </a>
#   <div  class="tb-megamenu-submenu dropdown-menu mega-dropdown-menu nav-child" data-class="" data-pixelsorfullwidth="0" data-width="" data-fullwidthtarget="" role="list">
#   <div class="mega-dropdown-inner container">
#           <div  class="tb-megamenu-row row-fluid">
#         <div  data-showblocktitle="1" class="tb-megamenu-column mega-col-nav col-md-3 col-lg-3 col-xl-12" data-class="" data-hidewcol="" id="tb-megamenu-column-8">
#   <div class="tb-megamenu-column-inner mega-inner clearfix">
#                  <div  class="tb-block tb-megamenu-block" data-type="block" data-block="navtopicbiosphere">
#     <div class="block-inner">
#       <div id="block-block-content86dedffe-4d61-4d18-80e5-6f448f4984da" data-block-plugin-id="block_content:86dedffe-4d61-4d18-80e5-6f448f4984da" class="block block-block-content block-block-content86dedffe-4d61-4d18-80e5-6f448f4984da">
#
#
#       <div class="content">
#
#             <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item"><h3 class="text-align-left">Biosphere</h3>
#
# <p class="text-align-left">The biosphere encompasses all life on Earth and extends from root systems to mountaintops and all depths of the ocean. It is critical for maintaining species diversity, regulating climate, and providing numerous ecosystem functions.</p>
#
# <p class="mt-2" style="text-align:center"><img alt="Biosphere" class="daac-landing-image" src="/sites/default/files/2021-08/biosphere-icon.png" width="150" /></p>
# </div>
#
#     </div>
#   </div>
#
#     </div>
#   </div>
#
#       </div>
# </div>
#
#   </div>
#
#       </div>
# </div>
#
# </li>
#
#
#
# <li  class="tb-megamenu-item level-2 mega dropdown-submenu" data-id="menu_link_content:8c734b32-2d34-4d52-8751-e27ec43ca0f8" data-level="2" data-type="menu_item" data-class="" data-xicon="" data-caption="" data-alignsub="" data-group="0" data-hidewcol="0" data-hidesub="0" data-label="" aria-level="2" >
#       <a href="/topics/cryosphere"  class="dropdown-toggle" aria-expanded="false">
#           Cryosphere
#           </a>
#   <div  class="tb-megamenu-submenu dropdown-menu mega-dropdown-menu nav-child" data-class="" data-pixelsorfullwidth="0" data-width="" data-fullwidthtarget="" role="list">
#   <div class="mega-dropdown-inner container">
#           <div  class="tb-megamenu-row row-fluid">
#         <div  data-showblocktitle="1" class="tb-megamenu-column mega-col-nav col-md-3 col-lg-3 col-xl-12" data-class="" data-hidewcol="" id="tb-megamenu-column-9">
#   <div class="tb-megamenu-column-inner mega-inner clearfix">
#                  <div  class="tb-block tb-megamenu-block" data-type="block" data-block="navtopiccryosphere">
#     <div class="block-inner">
#       <div id="block-block-contentf162df8e-7583-4abc-979f-616656480c43" data-block-plugin-id="block_content:f162df8e-7583-4abc-979f-616656480c43" class="block block-block-content block-block-contentf162df8e-7583-4abc-979f-616656480c43">
#
#
#       <div class="content">
#
#             <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item"><h3 class="text-align-left">Cryosphere</h3>
#
# <p class="text-align-left">The cryosphere encompasses the frozen parts of Earth, including glaciers and ice sheets, sea ice, and any other frozen body of water. The cryosphere plays a critical role in regulating climate and sea levels.</p>
#
# <p class="mt-2" style="text-align:center"><img alt="Cryosphere icon" src="/sites/default/files/2021-08/cryosphere-icon.png" width="150" /></p>
# </div>
#
#     </div>
#   </div>
#
#     </div>
#   </div>
#
#       </div>
# </div>
#
#   </div>
#
#       </div>
# </div>
#
# </li>
#
#
#
# <li  class="tb-megamenu-item level-2 mega dropdown-submenu" data-id="menu_link_content:4d78e7da-db58-4cb2-9689-6c2ee0f03ec9" data-level="2" data-type="menu_item" data-class="" data-xicon="" data-caption="" data-alignsub="" data-group="0" data-hidewcol="0" data-hidesub="0" data-label="" aria-level="2" >
#       <a href="/topics/human-dimensions"  class="dropdown-toggle" aria-expanded="false">
#           Human Dimensions
#           </a>
#   <div  class="tb-megamenu-submenu dropdown-menu mega-dropdown-menu nav-child" data-class="" data-pixelsorfullwidth="0" data-width="" data-fullwidthtarget="" role="list">
#   <div class="mega-dropdown-inner container">
#           <div  class="tb-megamenu-row row-fluid">
#         <div  data-showblocktitle="1" class="tb-megamenu-column mega-col-nav col-md-3 col-lg-3 col-xl-12" data-class="" data-hidewcol="" id="tb-megamenu-column-10">
#   <div class="tb-megamenu-column-inner mega-inner clearfix">
#                  <div  class="tb-block tb-megamenu-block" data-type="block" data-block="navtopichumandimensions">
#     <div class="block-inner">
#       <div id="block-block-contentc5fa936e-38ec-4dd5-987c-74f4339c9769" data-block-plugin-id="block_content:c5fa936e-38ec-4dd5-987c-74f4339c9769" class="block block-block-content block-block-contentc5fa936e-38ec-4dd5-987c-74f4339c9769">
#
#
#       <div class="content">
#
#             <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item"><h3 class="text-align-left">Human Dimensions</h3>
#
# <p class="text-align-left">The human dimensions discipline includes ways humans interact with the environment and how these interactions impact Earth’s systems. It also explores the vulnerability of human communities to natural disasters and hazards.</p>
#
# <p class="mt-2" style="text-align:center"><img alt="Human Dimensions icon" src="/sites/default/files/2021-08/human-dimensions-icon.png" width="150" /></p>
# </div>
#
#     </div>
#   </div>
#
#     </div>
#   </div>
#
#       </div>
# </div>
#
#   </div>
#
#       </div>
# </div>
#
# </li>
#
#
#
# <li  class="tb-megamenu-item level-2 mega dropdown-submenu" data-id="menu_link_content:1c0d7816-967d-431c-a6cf-3e87824bcb73" data-level="2" data-type="menu_item" data-class="" data-xicon="" data-caption="" data-alignsub="" data-group="0" data-hidewcol="0" data-hidesub="0" data-label="" aria-level="2" >
#       <a href="/topics/land-surface"  class="dropdown-toggle" aria-expanded="false">
#           Land Surface
#           </a>
#   <div  class="tb-megamenu-submenu dropdown-menu mega-dropdown-menu nav-child" data-class="" data-pixelsorfullwidth="0" data-width="" data-fullwidthtarget="" role="list">
#   <div class="mega-dropdown-inner container">
#           <div  class="tb-megamenu-row row-fluid">
#         <div  data-showblocktitle="1" class="tb-megamenu-column mega-col-nav col-md-3 col-lg-3 col-xl-12" data-class="" data-hidewcol="" id="tb-megamenu-column-11">
#   <div class="tb-megamenu-column-inner mega-inner clearfix">
#                  <div  class="tb-block tb-megamenu-block" data-type="block" data-block="navtopiclandsurface">
#     <div class="block-inner">
#       <div id="block-block-content5b72558e-5d5a-48b0-b98d-3cc132bac71a" data-block-plugin-id="block_content:5b72558e-5d5a-48b0-b98d-3cc132bac71a" class="block block-block-content block-block-content5b72558e-5d5a-48b0-b98d-3cc132bac71a">
#
#
#       <div class="content">
#
#             <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item"><h3 class="text-align-left">Land Surface</h3>
#
# <p class="text-align-left">The land surface discipline includes research into areas such as shrinking forests, warming land, and eroding soils. NASA data provide key information on land surface parameters and the ecological state of our planet.</p>
#
# <p class="mt-2" style="text-align:center"><img alt="Land Surface icon" src="/sites/default/files/2021-08/land-surface-icon.png" width="150" /></p>
# </div>
#
#     </div>
#   </div>
#
#     </div>
#   </div>
#
#       </div>
# </div>
#
#   </div>
#
#       </div>
# </div>
#
# </li>
#
#
#
# <li  class="tb-megamenu-item level-2 mega dropdown-submenu" data-id="menu_link_content:b1c2e93b-62e1-4dd9-b77e-04001d7765f9" data-level="2" data-type="menu_item" data-class="" data-xicon="" data-caption="" data-alignsub="" data-group="0" data-hidewcol="0" data-hidesub="0" data-label="" aria-level="2" >
#       <a href="/topics/ocean"  class="dropdown-toggle" aria-expanded="false">
#           Ocean
#           </a>
#   <div  class="tb-megamenu-submenu dropdown-menu mega-dropdown-menu nav-child" data-class="" data-pixelsorfullwidth="0" data-width="" data-fullwidthtarget="" role="list">
#   <div class="mega-dropdown-inner container">
#           <div  class="tb-megamenu-row row-fluid">
#         <div  data-showblocktitle="1" class="tb-megamenu-column mega-col-nav col-md-3 col-lg-3 col-xl-12" data-class="" data-hidewcol="" id="tb-megamenu-column-12">
#   <div class="tb-megamenu-column-inner mega-inner clearfix">
#                  <div  class="tb-block tb-megamenu-block" data-type="block" data-block="navtopicoceans">
#     <div class="block-inner">
#       <div id="block-block-contentfd6a78e8-5d88-4934-9c69-2fbffa5f0234" data-block-plugin-id="block_content:fd6a78e8-5d88-4934-9c69-2fbffa5f0234" class="block block-block-content block-block-contentfd6a78e8-5d88-4934-9c69-2fbffa5f0234">
#
#
#       <div class="content">
#
#             <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item"><h3 class="text-align-left">Ocean</h3>
#
# <p class="text-align-left">This vast, critical reservoir supports a diversity of life and helps regulate Earth’s climate.</p>
#
# <p class="mt-2" style="text-align:center"><img alt="Oceans icon" src="/sites/default/files/2021-08/ocean-icon.png" width="150" /></p>
# </div>
#
#     </div>
#   </div>
#
#     </div>
#   </div>
#
#       </div>
# </div>
#
#   </div>
#
#       </div>
# </div>
#
# </li>
#
#
#
# <li  class="tb-megamenu-item level-2 mega dropdown-submenu" data-id="menu_link_content:4eff4a6a-3fe4-4b79-9082-0c118de7bd5e" data-level="2" data-type="menu_item" data-class="" data-xicon="" data-caption="" data-alignsub="" data-group="0" data-hidewcol="0" data-hidesub="0" data-label="" aria-level="2" >
#       <a href="/topics/solid-earth"  class="dropdown-toggle" aria-expanded="false">
#           Solid Earth
#           </a>
#   <div  class="tb-megamenu-submenu dropdown-menu mega-dropdown-menu nav-child" data-class="" data-pixelsorfullwidth="0" data-width="" data-fullwidthtarget="" role="list">
#   <div class="mega-dropdown-inner container">
#           <div  class="tb-megamenu-row row-fluid">
#         <div  data-showblocktitle="1" class="tb-megamenu-column mega-col-nav col-md-3 col-lg-3 col-xl-12" data-class="" data-hidewcol="" id="tb-megamenu-column-13">
#   <div class="tb-megamenu-column-inner mega-inner clearfix">
#                  <div  class="tb-block tb-megamenu-block" data-type="block" data-block="navtopicsolidearth">
#     <div class="block-inner">
#       <div id="block-block-contentde073667-6588-447f-8e3d-ae2075224638" data-block-plugin-id="block_content:de073667-6588-447f-8e3d-ae2075224638" class="block block-block-content block-block-contentde073667-6588-447f-8e3d-ae2075224638">
#
#
#       <div class="content">
#
#             <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item"><h3 class="text-align-left">Solid Earth</h3>
#
# <p class="text-align-left">Processes occurring deep within Earth constantly are shaping landforms. Although originating from below the surface, these processes can be analyzed from ground, air, or space-based measurements.</p>
#
# <p class="mt-2" style="text-align:center"><img alt="Solid Earth icon" src="/sites/default/files/2021-08/solid-earth-icon.png" width="150" /></p>
# </div>
#
#     </div>
#   </div>
#
#     </div>
#   </div>
#
#       </div>
# </div>
#
#   </div>
#
#       </div>
# </div>
#
# </li>
#
#
#
# <li  class="tb-megamenu-item level-2 mega dropdown-submenu" data-id="menu_link_content:105fd739-8d6a-41e2-a7fb-26eb2ed4325f" data-level="2" data-type="menu_item" data-class="" data-xicon="" data-caption="" data-alignsub="" data-group="0" data-hidewcol="0" data-hidesub="0" data-label="" aria-level="2" >
#       <a href="/topics/sun-earth-interactions"  class="dropdown-toggle" aria-expanded="false">
#           Sun-Earth Interactions
#           </a>
#   <div  class="tb-megamenu-submenu dropdown-menu mega-dropdown-menu nav-child" data-class="" data-pixelsorfullwidth="0" data-width="" data-fullwidthtarget="" role="list">
#   <div class="mega-dropdown-inner container">
#           <div  class="tb-megamenu-row row-fluid">
#         <div  data-showblocktitle="1" class="tb-megamenu-column mega-col-nav col-md-3 col-lg-3 col-xl-12" data-class="" data-hidewcol="" id="tb-megamenu-column-14">
#   <div class="tb-megamenu-column-inner mega-inner clearfix">
#                  <div  class="tb-block tb-megamenu-block" data-type="block" data-block="navtopicsunearthinteractions">
#     <div class="block-inner">
#       <div id="block-block-contentd1b71b67-7eb4-4a26-b423-3147ecdf99a4" data-block-plugin-id="block_content:d1b71b67-7eb4-4a26-b423-3147ecdf99a4" class="block block-block-content block-block-contentd1b71b67-7eb4-4a26-b423-3147ecdf99a4">
#
#
#       <div class="content">
#
#             <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item"><h3 class="text-align-left">Sun-Earth Interactions</h3>
#
# <p class="text-align-left">The Sun influences a variety of physical and chemical processes in Earth’s atmosphere. NASA continually monitors solar radiation and its effect on the planet.</p>
#
# <p class="mt-2" style="text-align:center"><img alt="Sun-Earth Interactions icon" src="/sites/default/files/2021-08/sun-earth-interactions-icon.png" width="150" /></p>
# </div>
#
#     </div>
#   </div>
#
#     </div>
#   </div>
#
#       </div>
# </div>
#
#   </div>
#
#       </div>
# </div>
#
# </li>
#
#
#
# <li  class="tb-megamenu-item level-2 mega dropdown-submenu" data-id="menu_link_content:a197cc56-35e6-41c8-8e71-d0fe1f94b4f9" data-level="2" data-type="menu_item" data-class="" data-xicon="" data-caption="" data-alignsub="" data-group="0" data-hidewcol="0" data-hidesub="0" data-label="" aria-level="2" >
#       <a href="/topics/terrestrial-hydrosphere"  class="dropdown-toggle" aria-expanded="false">
#           Terrestrial Hydrosphere
#           </a>
#   <div  class="tb-megamenu-submenu dropdown-menu mega-dropdown-menu nav-child" data-class="" data-pixelsorfullwidth="0" data-width="" data-fullwidthtarget="" role="list">
#   <div class="mega-dropdown-inner container">
#           <div  class="tb-megamenu-row row-fluid">
#         <div  data-showblocktitle="1" class="tb-megamenu-column mega-col-nav col-md-3 col-lg-3 col-xl-12" data-class="" data-hidewcol="" id="tb-megamenu-column-15">
#   <div class="tb-megamenu-column-inner mega-inner clearfix">
#                  <div  class="tb-block tb-megamenu-block" data-type="block" data-block="navtopicterrestrialhydrosphere">
#     <div class="block-inner">
#       <div id="block-block-content725ab955-f6f5-4cae-bf68-e95a74d8894e" data-block-plugin-id="block_content:725ab955-f6f5-4cae-bf68-e95a74d8894e" class="block block-block-content block-block-content725ab955-f6f5-4cae-bf68-e95a74d8894e">
#
#
#       <div class="content">
#
#             <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item"><h3 class="text-align-left">Terrestrial Hydrosphere</h3>
#
# <p class="text-align-left">The terrestrial hydrosphere includes water on the land surface and underground in the form of lakes, rivers, and groundwater along with total water storage.</p>
#
# <p class="mt-2" style="text-align:center"><img alt="Terrestrial Hydrosphere icon" src="/sites/default/files/2021-08/terrestrial-hydrosphere-icon.png" width="150" /></p>
# </div>
#
#     </div>
#   </div>
#
#     </div>
#   </div>
#
#       </div>
# </div>
#
#   </div>
#
#       </div>
# </div>
#
# </li>
#
#   </ul>
#
#       </div>
# </div>
#
#         <div  data-showblocktitle="1" class="tb-megamenu-column span4 mega-col-nav" data-class="" data-width="4" data-hidewcol="" id="tb-megamenu-column-16">
#   <div class="tb-megamenu-column-inner mega-inner clearfix">
#                  <div  class="tb-block tb-megamenu-block" data-type="block" data-block="earthdata_branding">
#     <div class="block-inner">
#         <a href="/" title="Home" rel="home" class="navbar-brand">
#           <img src="/s3fs-public/earthdata-oaos-logo.png?VersionId=h5vKcBx45miaimU2tElXhOWilgws_kIs" alt="Home" class="img-fluid d-inline-block align-top" />
#         <span class="ml-2 d-none d-md-inline"></span>
#   </a>
#
#     </div>
#   </div>
#
#       </div>
# </div>
#
#   </div>
#
#       </div>
# </div>
#
# </li>
#
#
#
# <li  class="tb-megamenu-item level-1 mega mega-align-justify dropdown" data-id="menu_link_content:1250fc0e-fc01-483f-bad3-dcad3405a0ce" data-level="1" data-type="menu_item" data-class="" data-xicon="" data-caption="" data-alignsub="justify" data-group="0" data-hidewcol="0" data-hidesub="0" data-label="" aria-level="1" >
#       <a href="/learn"  class="dropdown-toggle" aria-expanded="false">
#           Learn
#           </a>
#   <div  class="tb-megamenu-submenu dropdown-menu mega-dropdown-menu nav-child fullwidth" data-class="" data-pixelsorfullwidth="1" data-width="" data-fullwidthtarget="#navbar-main" fullwidth-target="#navbar-main" role="list">
#   <div class="mega-dropdown-inner container">
#           <div  class="tb-megamenu-row row-fluid">
#         <div  data-showblocktitle="1" class="tb-megamenu-column span4 mega-col-nav" data-class="" data-width="4" data-hidewcol="0" id="tb-megamenu-column-17">
#   <div class="tb-megamenu-column-inner mega-inner clearfix">
#                  <div  class="tb-block tb-megamenu-block" data-type="block" data-block="navlearndescription">
#     <div class="block-inner">
#       <div id="block-block-content8fcb86dc-db25-4127-b573-939cab44e531" data-block-plugin-id="block_content:8fcb86dc-db25-4127-b573-939cab44e531" class="block block-block-content block-block-content8fcb86dc-db25-4127-b573-939cab44e531">
#
#
#       <div class="content">
#
#             <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item"><h2>Learn</h2>
#
# <p>Whether you are a scientist, an educator, a student, or are just interested in learning more about NASA’s Earth science data and how to use them, we have the resources to help. Get information and guides to help you find and use NASA Earth science data, services, and tools.</p>
#
# <div class="align-left">
#
#
#   <div class="field field--name-field-media-image field--type-image field--label-visually_hidden">
#     <div class="field__label visually-hidden">Image</div>
#               <div class="field__item">
# <a href="https://www.earthdata.nasa.gov/s3fs-public/2021-12/learn-nav-image.png?VersionId=aWb2AOrq0TWA1S.blcAnbck4BKhZxDMR" aria-controls="colorbox" aria-label="{&quot;title&quot;:&quot;Earthdata - Learn&quot;,&quot;alt&quot;:&quot;Learn navigation graphic - an illustration of 3 students.&quot;}" role="button" title="" data-colorbox-gallery="gallery-image-44817-aI68BhbglbM" class="colorbox" data-cbox-img-attrs="{&quot;title&quot;:&quot;Earthdata - Learn&quot;,&quot;alt&quot;:&quot;Learn navigation graphic - an illustration of 3 students.&quot;}"><img src="/s3fs-public/2021-12/learn-nav-image.png?VersionId=aWb2AOrq0TWA1S.blcAnbck4BKhZxDMR" width="350" height="162" alt="Learn navigation graphic - an illustration of 3 students." title="Earthdata - Learn" loading="lazy" typeof="foaf:Image" /></a>
# </div>
#           </div>
#
# </div>
# </div>
#
#     </div>
#   </div>
#
#     </div>
#   </div>
#
#       </div>
# </div>
#
#         <div  class="tb-megamenu-column span4 mega-col-nav" data-class="" data-width="4" data-hidewcol="" id="tb-megamenu-column-18">
#   <div class="tb-megamenu-column-inner mega-inner clearfix">
#                <ul  class="tb-megamenu-subnav mega-nav level-1 items-6" role="list">
#
#
# <li  class="tb-megamenu-item level-2 mega" data-id="menu_link_content:c674fd3f-75e5-4276-b864-1e4b7a722bf9" data-level="2" data-type="menu_item" data-class="" data-xicon="" data-caption="" data-alignsub="" data-group="0" data-hidewcol="0" data-hidesub="0" data-label="" aria-level="2" >
#       <a href="/learn/get-started" >
#           Get Started
#           </a>
#
# </li>
#
#
#
# <li  class="tb-megamenu-item level-2 mega" data-id="menu_link_content:228de00c-5768-428c-b4ac-852af9d60aa2" data-level="2" data-type="menu_item" data-class="" data-xicon="" data-caption="" data-alignsub="" data-group="0" data-hidewcol="0" data-hidesub="0" data-label="" aria-level="2" >
#       <a href="/learn/backgrounders" >
#           Backgrounders
#           </a>
#
# </li>
#
#
#
# <li  class="tb-megamenu-item level-2 mega" data-id="menu_link_content:1870d0cf-68be-43fc-95b7-d110b332d932" data-level="2" data-type="menu_item" data-class="" data-xicon="" data-caption="" data-alignsub="" data-group="0" data-hidewcol="0" data-hidesub="0" data-label="" aria-level="2" >
#       <a href="/learn/pathfinders" >
#           Data Pathfinders
#           </a>
#
# </li>
#
#
#
# <li  class="tb-megamenu-item level-2 mega" data-id="menu_link_content:e8b8894a-2e36-4e7c-ae64-bb392353721b" data-level="2" data-type="menu_item" data-class="" data-xicon="" data-caption="" data-alignsub="" data-group="0" data-hidewcol="0" data-hidesub="0" data-label="" aria-level="2" >
#       <a href="/learn/toolkits" >
# ...
#
# <div class="nav-child"><a href="https://firms.modaps.eosdis.nasa.gov/alerts/">fire email alerts</a></div>
#
# <div class="nav-child"><a href="https://firms.modaps.eosdis.nasa.gov/">fire map (global)</a></div>
#
# <div class="nav-child"><a href="https://firms.modaps.eosdis.nasa.gov/usfs/web-services/">fire map (us/canada)</a></div>
# </div>
#
# <div class="mobile-nav-section">
# <div class="mobile-nav-title"><a href="/topics">topics</a></div>
#
# <div><a href="/topics/atmosphere">atmosphere</a></div>
#
# <div><a href="/topics/biosphere">biosphere</a></div>
#
# <div><a href="/topics/cryosphere">cryosphere</a></div>
#
# <div><a href="/topics/human-dimensions">human dimensions</a></div>
#
# <div><a href="/topics/land-surface">land surface</a></div>
#
# <div><a href="/topics/ocean">ocean</a></div>
#
# <div><a href="/topics/solid-earth">solid earth</a></div>
#
# <div><a href="/topics/sun-earth-interactions">sun-earth interactions</a></div>
#
# <div><a href="/topics/terrestrial-hydrosphere">terrestrial hydrosphere</a></div>
# </div>
#
# <div class="mobile-nav-section">
# <div class="mobile-nav-title"><a href="/learn">learn</a></div>
#
# <div><a href="/learn/getting-started">get started</a></div>
#
# <div><a href="/learn/backgrounders">backgrounders</a></div>
#
# <div><a href="/learn/pathfinders">data pathfinders</a></div>
#
# <div><a href="/learn/toolkits">data toolkits</a></div>
#
# <div><a href="/learn/user-resources/webinars-and-tutorials">webinars and tutorials</a></div>
#
# <div class="nav-parent">data stories<i class="arrow-down"> </i></div>
#
# <div class="nav-child"><a href="/learn/articles">articles</a></div>
#
# <div class="nav-child"><a href="/learn/data-chat">data chats</a></div>
#
# <div class="nav-child"><a href="/learn/data-user-profiles">data user profiles</a></div>
# </div>
#
# <div class="mobile-nav-section">
# <div class="mobile-nav-title"><a href="/engage">engage</a></div>
#
# <div><a href="/engage/esds-public-private-partnerships">public &amp; private partnerships</a></div>
#
# <div><a href="/engage/memberships-and-affiliations">memberships &amp; affiliations</a></div>
#
# <div class="nav-parent"><a href="/engage/open-data-services-and-software">open data, services, and software policies<i class="arrow-down"> </i></a></div>
#
# <div class="nav-child"><a href="/engage/open-data-services-and-software/esds-open-source-policy">open source software policy</a></div>
#
# <div class="nav-child"><a href="/engage/open-data-services-and-software/api">application programing interfaces (APIs)</a></div>
#
# <div class="nav-child"><a href="/engage/ecc">earthdata code collaborative (ECC)</a></div>
#
# <div class="nav-parent"><a href="/engage/standards">standards<i class="arrow-down"> </i></a></div>
#
# <div class="nav-child"><a href="/esdis/eso/standards-and-references">data standards and requirements</a></div>
#
# <div class="nav-child"><a href="/use-data/data-use-policy">data use policy</a></div>
#
# <div class="nav-child"><a href="/use-data/data-citations-acknowledgements">data citations and acknowledgements</a></div>
#
# <div><a href="/engage/new-missions">adding new data to eosdis</a></div>
# </div>
#
# <div class="mobile-nav-section">
# <div class="mobile-nav-title"><a href="/esds">about</a></div>
#
# <div class="nav-parent"><a href="/esds">earth science data systems (esds) program<i class="arrow-down"> </i></a></div>
#
# <div class="nav-child"><a href="/esds/csda">commercial smallsat data acquisition (csda) program</a></div>
#
# <div class="nav-child"><a href="/esds/competitive-programs">competitive programs</a></div>
#
# <div class="nav-child"><a href="/esds/esds-program-components">esds program components</a></div>
#
# <div class="nav-child"><a href="/esds/impact">interagency implementation and advanced concepts team (impact)</a></div>
#
# <div><a href="/esdis">earth science data and information system (esdis) project</a></div>
#
# <div class="nav-parent"><a href="/eosdis">earth observing system data and information system (eosdis)<i class="arrow-down"> </i></a></div>
#
# <div class="nav-child"><a href="/eosdis/daacs">distributed active archive centers (daacs)</a></div>
#
# <div class="nav-child"><a href="/eosdis/system-performance">system performance and metrics</a></div>
#
# <div class="nav-child"><a href="/eosdis/science-system-description/eosdis-components">system components</a></div>
#
# <div class="nav-child"><a href="/eosdis/data-system-interfaces">data system interfaces</a></div>
# </div>
# </div>
# </div>
#
#     </div>
#   </div>
#
#
#                 	          </div>
#                                             </div>
#                   </nav>
#           </header>
#           <div class="highlighted">
#         <aside class="container section clearfix" role="complementary">
#             <div data-drupal-messages-fallback class="hidden"></div>
#
#
#         </aside>
#       </div>
#             <div id="main-wrapper" class="layout-main-wrapper clearfix">
#               <div id="main" class="container">
#             <div id="block-earthdata-breadcrumbs" data-block-plugin-id="system_breadcrumb_block" class="block block-system block-system-breadcrumb-block col-12 site-breadcrumbs">
#
#
#       <div class="content">
#
#
#   <nav role="navigation" aria-label="breadcrumb">
#     <ol class="breadcrumb">
#                   <li class="breadcrumb-item">
#           <a href="/">Earthdata</a>
#         </li>
#                         <li class="breadcrumb-item active">
#           System
#         </li>
#                         <li class="breadcrumb-item active">
#           Page Not Found
#         </li>
#               </ol>
#   </nav>
#
#     </div>
#   </div>
#
#
#           <div class="row row-offcanvas row-offcanvas-left clearfix mb-5">
#               <main class="main-content col" id="content" role="main">
#                 <section class="section">
#                   <a id="main-content" tabindex="-1"></a>
#                   <h2>404</h2>
#                   <p>Sorry! The page you were looking for does not exist.</p>
#                   <p>We've updated our website! Use the search bar or the navigation menu above to find the page you were looking for.</p>
#                   <p><a href="/">Click here</a> to return to the home page.</p>
#                 </section>
#               </main>
#                                   </div>
#         </div>
#           </div>
#         <footer class="site-footer">
#               <div class="container">
#                       <div class="site-footer__top clearfix">
#                 <section class="row region region-footer-first">
#     <div id="block-footernav" data-block-plugin-id="block_content:b090747a-252b-43b5-8b6e-dc8de20f476c" class="block block-block-content block-block-contentb090747a-252b-43b5-8b6e-dc8de20f476c">
#
#
#       <div class="content">
#
#             <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item"><div class="row col-12" id="footer-social">
# <div class="col-12 col-sm-12 col-md-6 justify-content-start d-sm-block d-md-flex w-100" id="footer-mailing-list">
# <div class="footer-contact mx-0 mx-sm-0 mx-md-1"><a href="/contact">Contact Us</a></div>
#
# <div class="footer-contact mx-0 mx-sm-0 mx-md-1"><a href="/subscribe">Subscribe</a></div>
#
# <div class="col-12 col-sm-12 col-md-6 justify-content-sm-start justify-content-md-end d-sm-block d-md-flex ms-auto" id="footer-social-icons">
# <div class="footer-social-title my-auto me-3">Follow Us</div>
#
# <div><a href="https://www.facebook.com/NASAEarthData" target="_blank"><img alt="fb_icon" class="footer-icon" src="/sites/default/files/icons/facebook-icon.png" /></a> <a href="https://twitter.com/NASAEarthData" target="_blank"> <img alt="twitter_icon" class="footer-icon" src="/sites/default/files/icons/twitter-icon.png" /></a> <a href="https://www.youtube.com/c/NASAEarthdata" target="_blank"> <img alt="yt_icon" class="footer-icon" src="/sites/default/files/icons/youtube-icon.png" /></a></div>
# </div>
# </div>
#
# <div class="py-3 my-auto d-none d-sm-none d-md-block">
# <hr /></div>
#
# <div class="row justify-content-center d-none d-sm-none d-md-flex" id="footer-nav">
# <div class="col-3">
# <div class="heading"><a href="/data">Data</a></div>
#
# <div><a href="/data/find-data">Find Data</a></div>
#
# <div class="child"><a href="https://search.earthdata.nasa.gov/">Earthdata Search</a></div>
#
# <div class="child"><a href="/eosdis/science-system-description/eosdis-components/cmr">Common Metadata Repository (CMR)</a></div>
#
# <div class="child"><a href="https://idn.ceos.org/" target="_blank">International Directory Network (IDN)</a></div>
#
# <div><a href="/data/use-data">Use Data</a></div>
#
# <div class="child"><a href="/tools">Data Tools</a></div>
#
# <div class="child"><a href="/recipes">Data Recipes</a></div>
#
# <div class="child"><a href="/worldview">Worldview</a></div>
#
# <div class="child"><a href="/worldview/worldview-image-archive">Worldview Image of the Week</a></div>
#
# <div class="child"><a href="/snapshots">Worldview Snapshots</a></div>
#
# <div class="child"><a href="/gibs">Global Imagery Browse Services (GIBS)</a></div>
#
# <div><a href="/learn/find-data/near-real-time">Land, Atmosphere Near Real-Time Data (LANCE)</a></div>
#
# <div><a href="/firms">FIRMS</a></div>
#
# <div class="child"><a href="/learn/find-data/near-real-time/firms/active-fire-data">Active Fire Data</a></div>
#
# <div class="child"><a href="https://firms.modaps.eosdis.nasa.gov/alerts/">Fire Email Alerts</a></div>
#
# <div class="child"><a href="https://firms.modaps.eosdis.nasa.gov/map/">Fire Map (Global)</a></div>
#
# <div class="child"><a href="https://firms.modaps.eosdis.nasa.gov/usfs/map">Fire Map (US/Canada)</a></div>
# </div>
#
# <div class="col-2">
# <div class="heading"><a href="/topics">Topics</a></div>
#
# <div><a href="/topics/atmosphere">Atmosphere</a></div>
#
# <div><a href="/topics/biosphere">Biosphere</a></div>
#
# <div><a href="/topics/cryosphere">Cryosphere</a></div>
#
# <div><a href="/topics/human-dimensions">Human Dimensions</a></div>
#
# <div><a href="/topics/land-surface">Land Surface</a></div>
#
# <div><a href="/topics/ocean">Ocean</a></div>
#
# <div><a href="/topics/solid-earth">Solid Earth</a></div>
#
# <div><a href="/topics/sun-earth-interactions">Sun-Earth Interactions</a></div>
#
# <div><a href="/topics/terrestrial-hydrosphere">Terrestrial Hydrosphere</a></div>
# </div>
#
# <div class="col-2">
# <div class="heading"><a href="/learn">Learn</a></div>
#
# <div><a href="/learn/get-started">Get Started</a></div>
#
# <div><a href="/learn/backgrounders">Backgrounders</a></div>
#
# <div><a href="/learn/pathfinders">Data Pathfinders</a></div>
#
# <div><a href="/learn/toolkits">Data Toolkits</a></div>
#
# <div><a href="/webinars">Webinars and Tutorials</a></div>
#
# <div>Data Stories</div>
#
# <div class="child"><a href="/learn/articles">Articles</a></div>
#
# <div class="child"><a href="/learn/data-user-profiles">Data User Profiles</a></div>
#
# <div class="child"><a href="/learn/data-chat">Data Chats</a></div>
# </div>
#
# <div class="col-2">
# <div class="heading"><a href="/engage">Engage</a></div>
#
# <div><a href="/engage/data-management-guidance">Data Management Guidance for ESD-Funded Researchers</a></div>
#
# <div><a href="/engage/open-data-services-and-software">Open Data, Services, and Software Policies</a></div>
#
# <div class="child"><a href="/engage/open-data-services-and-software/esds-open-source-policy">Open Source Software Policy</a></div>
#
# <div class="child"><a href="/api">Earthdata Developer Resources &amp; APIs</a></div>
#
# <div class="child"><a href="/ecc">Earthdata Code Collaborative</a></div>
#
# <div><a href="/esdis/eso/standards-and-references">Standards</a></div>
#
# <div class="child"><a href="/esdis/eso/standards-and-references">Data Standards and Requirements</a></div>
#
# <div class="child"><a href="/use-data/data-use-policy">Data Use Policy</a></div>
#
# <div class="child"><a href="/use-data/data-citations-acknowledgements">Data Citations and Acknowledgements</a></div>
#
# <div><a href="/adding-data">Adding Data to EOSDIS</a></div>
#
# <div><a href="/engage/esds-public-private-partnerships">Public/Private Partnerships</a></div>
#
# <div><a href="/engage/memberships-and-affiliations">Members and Affiliations</a></div>
# </div>
#
# <div class="col-3">
# <div class="heading"><a href="/about">About</a></div>
#
# <div><a href="/esds">ESDS Program</a></div>
#
# <div class="child"><a href="/esds/esds-program-components">ESDS Program Components</a></div>
#
# <div class="child"><a href="/esds/csda">Commercial Smallsat Data Acquisition (CSDA) Program</a></div>
#
# <div class="child"><a href="/esds/competitive-programs">Competitive Programs</a></div>
#
# <div class="child"><a href="/esds/impact">Interagency Implementation and Advanced Concepts Team (IMPACT)</a></div>
#
# <div><a href="/esdis">ESDIS Project</a></div>
#
# <div class="child"><a href="https://doclib.eosdis.nasa.gov/ords/f?p=104">ESDIS Project Library</a></div>
#
# <div class="child"><a href="https://ops1-cm.ems.eosdis.nasa.gov/cm2/">COMET (login required)</a></div>
#
# <div><a href="/eosdis">EOSDIS</a></div>
#
# <div class="child"><a href="/daacs">DAACs</a></div>
#
# <div class="child"><a href="/eosdis/system-performance">System Performance and Metrics</a></div>
#
# <div class="child"><a href="">System Components</a></div>
#
# <div class="child"><a href="/eosdis/data-system-interfaces">Data System Interfaces</a></div>
# </div>
# </div>
#
# <div class="py-3 my-auto d-none d-sm-none d-md-block">
# <hr /></div>
#
# <div class="footer-mobile d-block d-sm-block d-md-none">
# <div class="footer-social-title my-auto">More From Earthdata</div>
#
# <ul>
# 	<li><a href="/contact">Contact Us</a></li>
# 	<li><a href="https://forum.earthdata.nasa.gov/" target="_blank">Earthdata Forum</a></li>
# 	<li><a href="/learn/earthdata-user-community-forums">Community Forums</a></li>
# 	<li><a href="/support">Support</a></li>
# </ul>
# </div>
#
# <div class="compliance">
# <div class="footer-social-title my-auto d-block d-sm-block d-md-none">Related Links</div>
#
# <div class="text-md-center justify-content-center justify-content-sm-center justify-content-md-start justify-content-lg-center d-md-flex">
# <ul>
# 	<li class="d-none d-sm-none d-md-inline-block">NASA Official: Cerese Albers</li>
# 	<li><a href="https://www.nasa.gov/about/highlights/HP_Privacy.html" target="_blank">Web Privacy Policy</a></li>
# 	<li><a href="/engage/open-data-services-and-software/data-information-policy">Data and Information Policy</a></li>
# 	<li><a href="https://www.nasa.gov/audience/formedia/features/communication_policy.html" target="_blank">Communications Policy</a></li>
# 	<li><a href="https://www.nasa.gov/FOIA/index.html" target="_blank">Freedom of Information Act</a></li>
# 	<li><a href="https://www.usa.gov/" target="_blank">USA.gov</a></li>
# 	<li><a href="/sitemap.xml">Sitemap</a></li>
# </ul>
# </div>
#
# <div class="my-auto d-block d-sm-block d-md-none">
# <hr /></div>
#
# <div class="d-block d-sm-block d-md-none light-blue-text fw-bold">NASA Official: Cerese Albers</div>
# </div>
# </div>
# </div>
#
#     </div>
#   </div>
#
#   </section>
#
#                 <section class="region region-footer-second">
#     <div id="block-subfooter" data-block-plugin-id="block_content:968ad096-7934-42ed-975c-2977c99332fe" class="block block-block-content block-block-content968ad096-7934-42ed-975c-2977c99332fe">
#
#
#       <div class="content">
#
#     </div>
#   </div>
#
#   </section>
#
#
#
#             </div>
#                             </div>
#           </footer>
#   </div>
# </div>
#
#   </div>
#
#
#     <script src="/s3fs-public/js/js_qnBhz36fVpMPXctWcF6hYP0MjE67yiqA_Q_M2Oybods.js?VersionId=KnIsx01lyjGvrSFin84GtQlA5lbx4d1H"></script>
# <script src="https://static.addtoany.com/menu/page.js" async></script>
# <script src="/s3fs-public/js/js_azBlJXrDcGXIbRw5nR23VW3mbRyMoXfBj0GbLtj4q3Q.js?VersionId=Qy6EFzCCgSqi8MavqByiGmxoMUx.0rMF"></script>
# <script src="https://unpkg.com/slide-element@2/dist/index.umd.js"></script>
# <script src="/s3fs-public/js/js_Gy3gvLNpAHhbI87I_hO4jdk-icwEPj7cxVN9Nfkdhlc.js?VersionId=NtRmynjbSe5IF.Qcds74AucwaEqzhv6f"></script>
# <script src="//static.ctctcdn.com/js/signup-form-widget/current/signup-form-widget.min.js" defer async></script>
#
#   </body>
# </html>
#  404

# %%
from bs4 import BeautifulSoup

page = requests.get("https://www.earthdata.nasa.gov/engage/open-data-services-and-software/api")
soup = BeautifulSoup(page.content, 'html.parser')
title = soup.title.text # gets you the text of the <title>(...)</title>

# %%
import requests
from bs4 import BeautifulSoup

# Make a request to https://codedamn-classrooms.github.io/webscraper-python-codedamn-classroom-website/
page = requests.get(
    "https://www.earthdata.nasa.gov/engage/open-data-services-and-software/api")
soup = BeautifulSoup(page.content, 'html.parser')

# Extract title of page
page_title = soup.title.text

# print the result
print(page_title)
# Out:
# Earthdata Developer Portal | Earthdata

# %%
import requests
from bs4 import BeautifulSoup

# Make a request
page = requests.get(
    "https://www.earthdata.nasa.gov/engage/open-data-services-and-software/api")
soup = BeautifulSoup(page.content, 'html.parser')

# Extract title of page
page_title = soup.title.text

# Extract body of page
page_body = soup.body

# Extract head of page
page_head = soup.head

# print the result
print(page_body, page_head)
# Out:
# <body class="layout-no-sidebars page-node-43 path-node node--type-page">
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-WNP7MLF" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <a class="visually-hidden focusable skip-link" href="#main-content">
#       Skip to main content
#     </a>
# <div class="dialog-off-canvas-main-canvas" data-off-canvas-main-canvas="">
# <div id="page-wrapper">
# <div id="page">
# <header aria-label="Site header" class="header" id="header" role="banner">
# <div> <div class="container-fluid">
# <section class="row region region-site-wide-alerts">
# <div class="views-element-container block block-views block-views-blockalerts-block-1" data-block-plugin-id="views_block:alerts-block_1" id="block-views-block-alerts-block-1">
# <div class="content">
# <div><div class="view view-alerts view-id-alerts view-display-id-block_1 js-view-dom-id-80f1a96398417a9f7d9e6af6f059e75caa7ef12ac178aa6b31457c52c1d5bab9">
# </div>
# </div>
# </div>
# </div>
# <div class="views-element-container block block-views block-views-blockalerts-block-2" data-block-plugin-id="views_block:alerts-block_2" id="block-views-block-alerts-block-2">
# <div class="content">
# <div><div class="view view-alerts view-id-alerts view-display-id-block_2 js-view-dom-id-4908f3e8ac03979f382d0dd891e436e51289e96481237a347f316c6ca880b222">
# </div>
# </div>
# </div>
# </div>
# <div class="views-element-container block block-views block-views-blockalerts-block-3" data-block-plugin-id="views_block:alerts-block_3" id="block-views-block-alerts-block-3">
# <div class="content">
# <div><div class="view view-alerts view-id-alerts view-display-id-block_3 js-view-dom-id-24a39f46a4066038e272921785173fa4966f07e1c13d82124741c5939bab7563">
# </div>
# </div>
# </div>
# </div>
# </section>
# </div>
# </div>
# <nav class="navbar navbar-dark navbar-expand-lg pt-3 pb-2" id="navbar-main">
# <div class="container">
# <div class="mb-auto" id="home">
# <a class="navbar-brand" href="/" rel="home" title="Home">
# <img alt="Earthdata logo" class="logo" src="/sites/default/files/earthdata-oaos-logo.png"/>
# <img alt="Earthdata logo" class="logo-color" src="/sites/default/files/earthdata-oaos-logo-hover.png"/>
# </a>
# </div>
# <button aria-controls="CollapsingNavbar" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler navbar-toggler-right" data-target="#CollapsingNavbar" data-toggle="collapse" type="button"><span class="navbar-toggler-icon"></span></button>
# <div class="collapse navbar-collapse justify-content-end" id="CollapsingNavbar">
# <div class="block block-tb-megamenu block-tb-megamenu-menu-blockmain" data-block-plugin-id="tb_megamenu_menu_block:main" id="block-mainnavigation">
# <div class="content">
# <div aria-label="Main navigation" class="tb-megamenu tb-megamenu-main" role="navigation">
# <button class="btn btn-navbar tb-megamenu-button d-block d-sm-block d-md-block d-lg-none" data-target=".nav-collapse" data-toggle="collapse" type="button">
# <i class="fa fa-reorder"></i>
# </button>
# <div class="nav-collapse always-show">
# <ul class="tb-megamenu-nav nav level-0 items-5 d-none d-sm-none d-md-none d-lg-block" role="list">
# <li aria-level="1" class="tb-megamenu-item level-1 mega mega-align-justify dropdown" data-alignsub="justify" data-caption="" data-class="" data-group="0" data-hidesub="0" data-hidewcol="0" data-id="menu_link_content:9b027c3e-2abd-4d9e-844c-70b6c9475cd8" data-label="" data-level="1" data-type="menu_item" data-xicon="">
# <span aria-expanded="false" class="dropdown-toggle tb-megamenu-no-link" tabindex="0">
#           Data
#           </span>
# <div class="tb-megamenu-submenu dropdown-menu mega-dropdown-menu nav-child fullwidth" data-class="" data-fullwidthtarget="#navbar-main" data-pixelsorfullwidth="1" data-width="" fullwidth-target="#navbar-main" role="list">
# <div class="mega-dropdown-inner container">
# <div class="tb-megamenu-row row-fluid">
# <div class="tb-megamenu-column span4 mega-col-nav" data-class="" data-hidewcol="0" data-showblocktitle="1" data-width="4" id="tb-megamenu-column-1">
# <div class="tb-megamenu-column-inner mega-inner clearfix">
# <div class="tb-block tb-megamenu-block" data-block="navdatadescription" data-type="block">
# <div class="block-inner">
# <div class="block block-block-content block-block-contentaf9eda4c-f62c-41b2-b949-2941b9ce389f" data-block-plugin-id="block_content:af9eda4c-f62c-41b2-b949-2941b9ce389f" id="block-block-contentaf9eda4c-f62c-41b2-b949-2941b9ce389f">
# <div class="content">
# <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item"><h2>Data</h2>
# <p>Find and use NASA Earth science data fully, openly, and without restrictions.</p>
# <div class="d-grid gap-2"><a class="btn btn-green" href="/learn/get-started" role="button">Get Started</a> <a class="btn btn-green" href="/learn/find-data" role="button">Find Data</a> <a class="btn btn-green" href="/learn/use-data" role="button">Use Data</a></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="tb-megamenu-column span4 mega-col-nav" data-class="" data-hidewcol="" data-width="4" id="tb-megamenu-column-2">
# <div class="tb-megamenu-column-inner mega-inner clearfix">
# <ul class="tb-megamenu-subnav mega-nav level-1 items-8" role="list">
# <li aria-level="2" class="tb-megamenu-item level-2 mega" data-alignsub="" data-caption="" data-class="" data-group="0" data-hidesub="0" data-hidewcol="0" data-id="menu_link_content:e9f37aea-89bc-4a58-b603-01268d06a303" data-label="" data-level="2" data-type="menu_item" data-xicon="">
# <a href="https://search.earthdata.nasa.gov/">
#           Earthdata Search
#           </a>
# </li>
# <li aria-level="2" class="tb-megamenu-item level-2 mega" data-alignsub="" data-caption="" data-class="" data-group="0" data-hidesub="0" data-hidewcol="0" data-id="menu_link_content:6d3b9c4c-712d-4f7d-978d-7b92fad467ee" data-label="" data-level="2" data-type="menu_item" data-xicon="">
# <a href="/use-data/tools">
#           Data Tools
#           </a>
# </li>
# <li aria-level="2" class="tb-megamenu-item level-2 mega" data-alignsub="" data-caption="" data-class="" data-group="0" data-hidesub="0" data-hidewcol="0" data-id="menu_link_content:43eee3c7-52ac-43c8-b3de-2295344a1321" data-label="" data-level="2" data-type="menu_item" data-xicon="">
# <a href="/learn/data-recipes">
#           Data Recipes
#           </a>
# </li>
# <li aria-level="2" class="tb-megamenu-item level-2 mega" data-alignsub="" data-caption="" data-class="" data-group="0" data-hidesub="0" data-hidewcol="0" data-id="menu_link_content:291c2b38-38a7-432e-810c-3b4b8ba8a3fb" data-label="" data-level="2" data-type="menu_item" data-xicon="">
# <a href="/worldview">
#           Worldview
#           </a>
# </li>
# <li aria-level="2" class="tb-megamenu-item level-2 mega" data-alignsub="" data-caption="" data-class="" data-group="0" data-hidesub="0" data-hidewcol="0" data-id="menu_link_content:626c86cd-d7e7-433c-8424-2b38cb479214" data-label="" data-level="2" data-type="menu_item" data-xicon="">
# <a href="/worldview/worldview-image-archive">
#           Worldview Image of the Week
#           </a>
# </li>
# <li aria-level="2" class="tb-megamenu-item level-2 mega" data-alignsub="" data-caption="" data-class="" data-group="0" data-hidesub="0" data-hidewcol="0" data-id="menu_link_content:dfd8d16b-2993-44fe-8a60-5966edce70d2" data-label="" data-level="2" data-type="menu_item" data-xicon="">
# <a href="/worldview/worldview-snapshots">
#           Worldview Snapshots
#           </a>
# </li>
# <li aria-level="2" class="tb-megamenu-item level-2 mega" data-alignsub="" data-caption="" data-class="" data-group="0" data-hidesub="0" data-hidewcol="0" data-id="menu_link_content:c33f8206-4303-44f2-ada7-52c6bf45f6d5" data-label="" data-level="2" data-type="menu_item" data-xicon="">
# <a href="/eosdis/science-system-description/eosdis-components/gibs">
#           Global Imagery Browse Services (GIBS)
#           </a>
# </li>
# <li aria-level="2" class="tb-megamenu-item level-2 mega" data-alignsub="" data-caption="" data-class="" data-group="0" data-hidesub="0" data-hidewcol="0" data-id="menu_link_content:a16f897a-012e-4201-bb02-958aae8686d6" data-label="" data-level="2" data-type="menu_item" data-xicon="">
# <a href="/eosdis/science-system-description/eosdis-components/cmr">
#           Common Metadata Repository (CMR)
#           </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="tb-megamenu-column span4 mega-col-nav" data-class="" data-hidewcol="" data-width="4" id="tb-megamenu-column-3">
# <div class="tb-megamenu-column-inner mega-inner clearfix">
# <ul class="tb-megamenu-subnav mega-nav level-1 items-2" role="list">
# <li aria-level="2" class="tb-megamenu-item level-2 mega" data-alignsub="" data-caption="" data-class="" data-group="0" data-hidesub="0" data-hidewcol="0" data-id="menu_link_content:23a0d1f5-b0d7-4b70-ad2b-d4368987fea8" data-label="" data-level="2" data-type="menu_item" data-xicon="">
# <a href="/learn/find-data/near-real-time">
#           Land, Atmosphere Near Real-Time Data (LANCE)
#           </a>
# </li>
# <li aria-level="2" class="tb-megamenu-item level-2 mega mega-group" data-alignsub="" data-caption="" data-class="" data-group="1" data-hidesub="0" data-hidewcol="0" data-id="menu_link_content:4fe14958-1f3e-474a-9afd-2e6c9d389514" data-label="" data-level="2" data-type="menu_item" data-xicon="">
# <a aria-expanded="false" class="mega-group-title" href="/find-data/near-real-time/firms">
#           Fire Information for Resource Management System (FIRMS)
#           </a>
# <div class="tb-megamenu-submenu mega-group-ct nav-child" data-class="" data-fullwidthtarget="" data-pixelsorfullwidth="0" data-width="" role="list">
# <div class="mega-dropdown-inner container">
# <div class="tb-megamenu-row row-fluid">
# <div class="tb-megamenu-column mega-col-nav col-md-3 col-lg-3 col-xl-12" data-class="" data-hidewcol="0" id="tb-megamenu-column-4">
# <div class="tb-megamenu-column-inner mega-inner clearfix">
# <ul class="tb-megamenu-subnav mega-nav level-2 items-4" role="list">
# <li aria-level="3" class="tb-megamenu-item level-3 mega" data-alignsub="" data-caption="" data-class="" data-group="0" data-hidesub="0" data-hidewcol="0" data-id="menu_link_content:b38d6b2b-71b6-4c88-8743-7f6de3404dd0" data-label="" data-level="3" data-type="menu_item" data-xicon="">
# <a href="/learn/find-data/near-real-time/firms/active-fire-data">
#           Active Fire Data
#           </a>
# </li>
# <li aria-level="3" class="tb-megamenu-item level-3 mega" data-alignsub="" data-caption="" data-class="" data-group="0" data-hidesub="0" data-hidewcol="0" data-id="menu_link_content:88fc7e06-162c-4030-8ad1-b680a772f185" data-label="" data-level="3" data-type="menu_item" data-xicon="">
# <a href="https://firms.modaps.eosdis.nasa.gov/alerts/">
#           Fire Email Alerts
#           </a>
# </li>
# <li aria-level="3" class="tb-megamenu-item level-3 mega" data-alignsub="" data-caption="" data-class="" data-group="0" data-hidesub="0" data-hidewcol="0" data-id="menu_link_content:3639fc7e-4c72-458f-befc-74deb1f8bef7" data-label="" data-level="3" data-type="menu_item" data-xicon="">
# <a href="https://firms.modaps.eosdis.nasa.gov/map/">
#           Fire Map (Global)
#           </a>
# </li>
# <li aria-level="3" class="tb-megamenu-item level-3 mega" data-alignsub="" data-caption="" data-class="" data-group="0" data-hidesub="0" data-hidewcol="0" data-id="menu_link_content:bb05528b-af0e-4788-a9f7-73f136c0fdf6" data-label="" data-level="3" data-type="menu_item" data-xicon="">
# <a href="https://firms.modaps.eosdis.nasa.gov/usfs/map">
#           Fire Map (US/Canada)
#           </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li aria-level="1" class="tb-megamenu-item level-1 mega mega-align-justify dropdown" data-alignsub="justify" data-caption="" data-class="" data-group="0" data-hidesub="0" data-hidewcol="0" data-id="menu_link_content:91363c52-b5bb-4d10-8d66-476993fd3a28" data-label="" data-level="1" data-type="menu_item" data-xicon="">
# <a aria-expanded="false" class="dropdown-toggle" href="/topics">
#           Topics
#           </a>
# <div class="tb-megamenu-submenu dropdown-menu mega-dropdown-menu nav-child fullwidth" data-class="" data-fullwidthtarget="#navbar-main" data-pixelsorfullwidth="1" data-width="" fullwidth-target="#navbar-main" role="list">
# <div class="mega-dropdown-inner container">
# <div class="tb-megamenu-row row-fluid">
# <div class="tb-megamenu-column span4 mega-col-nav" data-class="" data-hidewcol="0" data-showblocktitle="1" data-width="4" id="tb-megamenu-column-5">
# <div class="tb-megamenu-column-inner mega-inner clearfix">
# <div class="tb-block tb-megamenu-block" data-block="navtopicsdescription" data-type="block">
# <div class="block-inner">
# <div class="block block-block-content block-block-content935b09e7-c611-4c7d-b2c0-6995a5918e17" data-block-plugin-id="block_content:935b09e7-c611-4c7d-b2c0-6995a5918e17" id="block-block-content935b09e7-c611-4c7d-b2c0-6995a5918e17">
# <div class="content">
# <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item"><h2>Topics</h2>
# <p>Recognizing the connections between interdependent Earth systems is critical for understanding the world in which we live.</p>
# <div class="align-left">
# <div class="field field--name-field-media-image field--type-image field--label-visually_hidden">
# <div class="field__label visually-hidden">Image</div>
# <div class="field__item">
# <a aria-controls="colorbox" aria-label='{"title":"Earthdata Topics","alt":"Topics navigation graphic - a globe and magnifying glass."}' class="colorbox" data-cbox-img-attrs='{"title":"Earthdata Topics","alt":"Topics navigation graphic - a globe and magnifying glass."}' data-colorbox-gallery="gallery-image-44816-GWyOcHOeV7k" href="https://www.earthdata.nasa.gov/s3fs-public/2021-12/topics-nav-image.png?VersionId=QMAaSpRww7HoOsbxodDTFP9MPWmaR.3t" role="button" title=""><img alt="Topics navigation graphic - a globe and magnifying glass." height="183" loading="lazy" src="/s3fs-public/2021-12/topics-nav-image.png?VersionId=QMAaSpRww7HoOsbxodDTFP9MPWmaR.3t" title="Earthdata Topics" typeof="foaf:Image" width="350"/></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="tb-megamenu-column span4 mega-col-nav" data-class="" data-hidewcol="" data-width="4" id="tb-megamenu-column-6">
# <div class="tb-megamenu-column-inner mega-inner clearfix">
# <ul class="tb-megamenu-subnav mega-nav level-1 items-9" role="list">
# <li aria-level="2" class="tb-megamenu-item level-2 mega dropdown-submenu" data-alignsub="" data-caption="" data-class="" data-group="0" data-hidesub="0" data-hidewcol="0" data-id="menu_link_content:5331f5e2-7f2e-4224-b3b3-0a2592f5fe19" data-label="" data-level="2" data-type="menu_item" data-xicon="">
# <a aria-expanded="false" class="dropdown-toggle" href="/topics/atmosphere">
#           Atmosphere
#           </a>
# <div class="tb-megamenu-submenu dropdown-menu mega-dropdown-menu nav-child" data-class="" data-fullwidthtarget="" data-pixelsorfullwidth="0" data-width="" role="list">
# <div class="mega-dropdown-inner container">
# <div class="tb-megamenu-row row-fluid">
# <div class="tb-megamenu-column mega-col-nav col-md-3 col-lg-3 col-xl-12" data-class="" data-hidewcol="" data-showblocktitle="1" id="tb-megamenu-column-7">
# <div class="tb-megamenu-column-inner mega-inner clearfix">
# <div class="tb-block tb-megamenu-block" data-block="navtopicatmosphere" data-type="block">
# <div class="block-inner">
# <div class="block block-block-content block-block-contentdbbd2bf0-3ea1-498c-a4a4-cce81d392772" data-block-plugin-id="block_content:dbbd2bf0-3ea1-498c-a4a4-cce81d392772" id="block-block-contentdbbd2bf0-3ea1-498c-a4a4-cce81d392772">
# <div class="content">
# <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item"><h3 class="text-align-left">Atmosphere</h3>
# <p class="text-align-left">The atmosphere is a gaseous envelope surrounding and protecting our planet from the intense radiation of the Sun and serves as a key interface between the terrestrial and ocean cycles.</p>
# <p class="mt-2" style="text-align:center"><img alt="Atmosphere icon" src="/sites/default/files/2021-08/atmosphere-icon.png" width="150"/></p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li aria-level="2" class="tb-megamenu-item level-2 mega dropdown-submenu" data-alignsub="" data-caption="" data-class="" data-group="0" data-hidesub="0" data-hidewcol="0" data-id="menu_link_content:1cd33c55-e90a-4395-a388-36282bc05335" data-label="" data-level="2" data-type="menu_item" data-xicon="">
# <a aria-expanded="false" class="dropdown-toggle" href="/topics/biosphere">
#           Biosphere
#           </a>
# <div class="tb-megamenu-submenu dropdown-menu mega-dropdown-menu nav-child" data-class="" data-fullwidthtarget="" data-pixelsorfullwidth="0" data-width="" role="list">
# <div class="mega-dropdown-inner container">
# <div class="tb-megamenu-row row-fluid">
# <div class="tb-megamenu-column mega-col-nav col-md-3 col-lg-3 col-xl-12" data-class="" data-hidewcol="" data-showblocktitle="1" id="tb-megamenu-column-8">
# <div class="tb-megamenu-column-inner mega-inner clearfix">
# <div class="tb-block tb-megamenu-block" data-block="navtopicbiosphere" data-type="block">
# <div class="block-inner">
# <div class="block block-block-content block-block-content86dedffe-4d61-4d18-80e5-6f448f4984da" data-block-plugin-id="block_content:86dedffe-4d61-4d18-80e5-6f448f4984da" id="block-block-content86dedffe-4d61-4d18-80e5-6f448f4984da">
# <div class="content">
# <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item"><h3 class="text-align-left">Biosphere</h3>
# <p class="text-align-left">The biosphere encompasses all life on Earth and extends from root systems to mountaintops and all depths of the ocean. It is critical for maintaining species diversity, regulating climate, and providing numerous ecosystem functions.</p>
# <p class="mt-2" style="text-align:center"><img alt="Biosphere" class="daac-landing-image" src="/sites/default/files/2021-08/biosphere-icon.png" width="150"/></p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li aria-level="2" class="tb-megamenu-item level-2 mega dropdown-submenu" data-alignsub="" data-caption="" data-class="" data-group="0" data-hidesub="0" data-hidewcol="0" data-id="menu_link_content:8c734b32-2d34-4d52-8751-e27ec43ca0f8" data-label="" data-level="2" data-type="menu_item" data-xicon="">
# <a aria-expanded="false" class="dropdown-toggle" href="/topics/cryosphere">
#           Cryosphere
#           </a>
# <div class="tb-megamenu-submenu dropdown-menu mega-dropdown-menu nav-child" data-class="" data-fullwidthtarget="" data-pixelsorfullwidth="0" data-width="" role="list">
# <div class="mega-dropdown-inner container">
# <div class="tb-megamenu-row row-fluid">
# <div class="tb-megamenu-column mega-col-nav col-md-3 col-lg-3 col-xl-12" data-class="" data-hidewcol="" data-showblocktitle="1" id="tb-megamenu-column-9">
# <div class="tb-megamenu-column-inner mega-inner clearfix">
# <div class="tb-block tb-megamenu-block" data-block="navtopiccryosphere" data-type="block">
# <div class="block-inner">
# <div class="block block-block-content block-block-contentf162df8e-7583-4abc-979f-616656480c43" data-block-plugin-id="block_content:f162df8e-7583-4abc-979f-616656480c43" id="block-block-contentf162df8e-7583-4abc-979f-616656480c43">
# <div class="content">
# <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item"><h3 class="text-align-left">Cryosphere</h3>
# <p class="text-align-left">The cryosphere encompasses the frozen parts of Earth, including glaciers and ice sheets, sea ice, and any other frozen body of water. The cryosphere plays a critical role in regulating climate and sea levels.</p>
# <p class="mt-2" style="text-align:center"><img alt="Cryosphere icon" src="/sites/default/files/2021-08/cryosphere-icon.png" width="150"/></p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li aria-level="2" class="tb-megamenu-item level-2 mega dropdown-submenu" data-alignsub="" data-caption="" data-class="" data-group="0" data-hidesub="0" data-hidewcol="0" data-id="menu_link_content:4d78e7da-db58-4cb2-9689-6c2ee0f03ec9" data-label="" data-level="2" data-type="menu_item" data-xicon="">
# <a aria-expanded="false" class="dropdown-toggle" href="/topics/human-dimensions">
#           Human Dimensions
#           </a>
# <div class="tb-megamenu-submenu dropdown-menu mega-dropdown-menu nav-child" data-class="" data-fullwidthtarget="" data-pixelsorfullwidth="0" data-width="" role="list">
# <div class="mega-dropdown-inner container">
# <div class="tb-megamenu-row row-fluid">
# <div class="tb-megamenu-column mega-col-nav col-md-3 col-lg-3 col-xl-12" data-class="" data-hidewcol="" data-showblocktitle="1" id="tb-megamenu-column-10">
# <div class="tb-megamenu-column-inner mega-inner clearfix">
# <div class="tb-block tb-megamenu-block" data-block="navtopichumandimensions" data-type="block">
# <div class="block-inner">
# <div class="block block-block-content block-block-contentc5fa936e-38ec-4dd5-987c-74f4339c9769" data-block-plugin-id="block_content:c5fa936e-38ec-4dd5-987c-74f4339c9769" id="block-block-contentc5fa936e-38ec-4dd5-987c-74f4339c9769">
# <div class="content">
# <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item"><h3 class="text-align-left">Human Dimensions</h3>
# <p class="text-align-left">The human dimensions discipline includes ways humans interact with the environment and how these interactions impact Earth’s systems. It also explores the vulnerability of human communities to natural disasters and hazards.</p>
# <p class="mt-2" style="text-align:center"><img alt="Human Dimensions icon" src="/sites/default/files/2021-08/human-dimensions-icon.png" width="150"/></p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li aria-level="2" class="tb-megamenu-item level-2 mega dropdown-submenu" data-alignsub="" data-caption="" data-class="" data-group="0" data-hidesub="0" data-hidewcol="0" data-id="menu_link_content:1c0d7816-967d-431c-a6cf-3e87824bcb73" data-label="" data-level="2" data-type="menu_item" data-xicon="">
# <a aria-expanded="false" class="dropdown-toggle" href="/topics/land-surface">
#           Land Surface
#           </a>
# <div class="tb-megamenu-submenu dropdown-menu mega-dropdown-menu nav-child" data-class="" data-fullwidthtarget="" data-pixelsorfullwidth="0" data-width="" role="list">
# <div class="mega-dropdown-inner container">
# <div class="tb-megamenu-row row-fluid">
# <div class="tb-megamenu-column mega-col-nav col-md-3 col-lg-3 col-xl-12" data-class="" data-hidewcol="" data-showblocktitle="1" id="tb-megamenu-column-11">
# <div class="tb-megamenu-column-inner mega-inner clearfix">
# <div class="tb-block tb-megamenu-block" data-block="navtopiclandsurface" data-type="block">
# <div class="block-inner">
# <div class="block block-block-content block-block-content5b72558e-5d5a-48b0-b98d-3cc132bac71a" data-block-plugin-id="block_content:5b72558e-5d5a-48b0-b98d-3cc132bac71a" id="block-block-content5b72558e-5d5a-48b0-b98d-3cc132bac71a">
# <div class="content">
# <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item"><h3 class="text-align-left">Land Surface</h3>
# <p class="text-align-left">The land surface discipline includes research into areas such as shrinking forests, warming land, and eroding soils. NASA data provide key information on land surface parameters and the ecological state of our planet.</p>
# <p class="mt-2" style="text-align:center"><img alt="Land Surface icon" src="/sites/default/files/2021-08/land-surface-icon.png" width="150"/></p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li aria-level="2" class="tb-megamenu-item level-2 mega dropdown-submenu" data-alignsub="" data-caption="" data-class="" data-group="0" data-hidesub="0" data-hidewcol="0" data-id="menu_link_content:b1c2e93b-62e1-4dd9-b77e-04001d7765f9" data-label="" data-level="2" data-type="menu_item" data-xicon="">
# <a aria-expanded="false" class="dropdown-toggle" href="/topics/ocean">
#           Ocean
#           </a>
# <div class="tb-megamenu-submenu dropdown-menu mega-dropdown-menu nav-child" data-class="" data-fullwidthtarget="" data-pixelsorfullwidth="0" data-width="" role="list">
# <div class="mega-dropdown-inner container">
# <div class="tb-megamenu-row row-fluid">
# <div class="tb-megamenu-column mega-col-nav col-md-3 col-lg-3 col-xl-12" data-class="" data-hidewcol="" data-showblocktitle="1" id="tb-megamenu-column-12">
# <div class="tb-megamenu-column-inner mega-inner clearfix">
# <div class="tb-block tb-megamenu-block" data-block="navtopicoceans" data-type="block">
# <div class="block-inner">
# <div class="block block-block-content block-block-contentfd6a78e8-5d88-4934-9c69-2fbffa5f0234" data-block-plugin-id="block_content:fd6a78e8-5d88-4934-9c69-2fbffa5f0234" id="block-block-contentfd6a78e8-5d88-4934-9c69-2fbffa5f0234">
# <div class="content">
# <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item"><h3 class="text-align-left">Ocean</h3>
# <p class="text-align-left">This vast, critical reservoir supports a diversity of life and helps regulate Earth’s climate.</p>
# <p class="mt-2" style="text-align:center"><img alt="Oceans icon" src="/sites/default/files/2021-08/ocean-icon.png" width="150"/></p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li aria-level="2" class="tb-megamenu-item level-2 mega dropdown-submenu" data-alignsub="" data-caption="" data-class="" data-group="0" data-hidesub="0" data-hidewcol="0" data-id="menu_link_content:4eff4a6a-3fe4-4b79-9082-0c118de7bd5e" data-label="" data-level="2" data-type="menu_item" data-xicon="">
# <a aria-expanded="false" class="dropdown-toggle" href="/topics/solid-earth">
#           Solid Earth
#           </a>
# <div class="tb-megamenu-submenu dropdown-menu mega-dropdown-menu nav-child" data-class="" data-fullwidthtarget="" data-pixelsorfullwidth="0" data-width="" role="list">
# <div class="mega-dropdown-inner container">
# <div class="tb-megamenu-row row-fluid">
# <div class="tb-megamenu-column mega-col-nav col-md-3 col-lg-3 col-xl-12" data-class="" data-hidewcol="" data-showblocktitle="1" id="tb-megamenu-column-13">
# <div class="tb-megamenu-column-inner mega-inner clearfix">
# <div class="tb-block tb-megamenu-block" data-block="navtopicsolidearth" data-type="block">
# <div class="block-inner">
# <div class="block block-block-content block-block-contentde073667-6588-447f-8e3d-ae2075224638" data-block-plugin-id="block_content:de073667-6588-447f-8e3d-ae2075224638" id="block-block-contentde073667-6588-447f-8e3d-ae2075224638">
# <div class="content">
# <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item"><h3 class="text-align-left">Solid Earth</h3>
# <p class="text-align-left">Processes occurring deep within Earth constantly are shaping landforms. Although originating from below the surface, these processes can be analyzed from ground, air, or space-based measurements.</p>
# <p class="mt-2" style="text-align:center"><img alt="Solid Earth icon" src="/sites/default/files/2021-08/solid-earth-icon.png" width="150"/></p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li aria-level="2" class="tb-megamenu-item level-2 mega dropdown-submenu" data-alignsub="" data-caption="" data-class="" data-group="0" data-hidesub="0" data-hidewcol="0" data-id="menu_link_content:105fd739-8d6a-41e2-a7fb-26eb2ed4325f" data-label="" data-level="2" data-type="menu_item" data-xicon="">
# <a aria-expanded="false" class="dropdown-toggle" href="/topics/sun-earth-interactions">
#           Sun-Earth Interactions
#           </a>
# <div class="tb-megamenu-submenu dropdown-menu mega-dropdown-menu nav-child" data-class="" data-fullwidthtarget="" data-pixelsorfullwidth="0" data-width="" role="list">
# <div class="mega-dropdown-inner container">
# <div class="tb-megamenu-row row-fluid">
# <div class="tb-megamenu-column mega-col-nav col-md-3 col-lg-3 col-xl-12" data-class="" data-hidewcol="" data-showblocktitle="1" id="tb-megamenu-column-14">
# <div class="tb-megamenu-column-inner mega-inner clearfix">
# <div class="tb-block tb-megamenu-block" data-block="navtopicsunearthinteractions" data-type="block">
# <div class="block-inner">
# <div class="block block-block-content block-block-contentd1b71b67-7eb4-4a26-b423-3147ecdf99a4" data-block-plugin-id="block_content:d1b71b67-7eb4-4a26-b423-3147ecdf99a4" id="block-block-contentd1b71b67-7eb4-4a26-b423-3147ecdf99a4">
# <div class="content">
# <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item"><h3 class="text-align-left">Sun-Earth Interactions</h3>
# <p class="text-align-left">The Sun influences a variety of physical and chemical processes in Earth’s atmosphere. NASA continually monitors solar radiation and its effect on the planet.</p>
# <p class="mt-2" style="text-align:center"><img alt="Sun-Earth Interactions icon" src="/sites/default/files/2021-08/sun-earth-interactions-icon.png" width="150"/></p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li aria-level="2" class="tb-megamenu-item level-2 mega dropdown-submenu" data-alignsub="" data-caption="" data-class="" data-group="0" data-hidesub="0" data-hidewcol="0" data-id="menu_link_content:a197cc56-35e6-41c8-8e71-d0fe1f94b4f9" data-label="" data-level="2" data-type="menu_item" data-xicon="">
# <a aria-expanded="false" class="dropdown-toggle" href="/topics/terrestrial-hydrosphere">
#           Terrestrial Hydrosphere
#           </a>
# <div class="tb-megamenu-submenu dropdown-menu mega-dropdown-menu nav-child" data-class="" data-fullwidthtarget="" data-pixelsorfullwidth="0" data-width="" role="list">
# <div class="mega-dropdown-inner container">
# <div class="tb-megamenu-row row-fluid">
# <div class="tb-megamenu-column mega-col-nav col-md-3 col-lg-3 col-xl-12" data-class="" data-hidewcol="" data-showblocktitle="1" id="tb-megamenu-column-15">
# <div class="tb-megamenu-column-inner mega-inner clearfix">
# <div class="tb-block tb-megamenu-block" data-block="navtopicterrestrialhydrosphere" data-type="block">
# <div class="block-inner">
# <div class="block block-block-content block-block-content725ab955-f6f5-4cae-bf68-e95a74d8894e" data-block-plugin-id="block_content:725ab955-f6f5-4cae-bf68-e95a74d8894e" id="block-block-content725ab955-f6f5-4cae-bf68-e95a74d8894e">
# <div class="content">
# <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item"><h3 class="text-align-left">Terrestrial Hydrosphere</h3>
# <p class="text-align-left">The terrestrial hydrosphere includes water on the land surface and underground in the form of lakes, rivers, and groundwater along with total water storage.</p>
# <p class="mt-2" style="text-align:center"><img alt="Terrestrial Hydrosphere icon" src="/sites/default/files/2021-08/terrestrial-hydrosphere-icon.png" width="150"/></p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="tb-megamenu-column span4 mega-col-nav" data-class="" data-hidewcol="" data-showblocktitle="1" data-width="4" id="tb-megamenu-column-16">
# <div class="tb-megamenu-column-inner mega-inner clearfix">
# <div class="tb-block tb-megamenu-block" data-block="earthdata_branding" data-type="block">
# <div class="block-inner">
# <a class="navbar-brand" href="/" rel="home" title="Home">
# <img alt="Home" class="img-fluid d-inline-block align-top" src="/s3fs-public/earthdata-oaos-logo.png?VersionId=h5vKcBx45miaimU2tElXhOWilgws_kIs"/>
# <span class="ml-2 d-none d-md-inline"></span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li aria-level="1" class="tb-megamenu-item level-1 mega mega-align-justify dropdown" data-alignsub="justify" data-caption="" data-class="" data-group="0" data-hidesub="0" data-hidewcol="0" data-id="menu_link_content:1250fc0e-fc01-483f-bad3-dcad3405a0ce" data-label="" data-level="1" data-type="menu_item" data-xicon="">
# <a aria-expanded="false" class="dropdown-toggle" href="/learn">
#           Learn
#           </a>
# <div class="tb-megamenu-submenu dropdown-menu mega-dropdown-menu nav-child fullwidth" data-class="" data-fullwidthtarget="#navbar-main" data-pixelsorfullwidth="1" data-width="" fullwidth-target="#navbar-main" role="list">
# <div class="mega-dropdown-inner container">
# <div class="tb-megamenu-row row-fluid">
# <div class="tb-megamenu-column span4 mega-col-nav" data-class="" data-hidewcol="0" data-showblocktitle="1" data-width="4" id="tb-megamenu-column-17">
# <div class="tb-megamenu-column-inner mega-inner clearfix">
# <div class="tb-block tb-megamenu-block" data-block="navlearndescription" data-type="block">
# <div class="block-inner">
# <div class="block block-block-content block-block-content8fcb86dc-db25-4127-b573-939cab44e531" data-block-plugin-id="block_content:8fcb86dc-db25-4127-b573-939cab44e531" id="block-block-content8fcb86dc-db25-4127-b573-939cab44e531">
# <div class="content">
# <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item"><h2>Learn</h2>
# <p>Whether you are a scientist, an educator, a student, or are just interested in learning more about NASA’s Earth science data and how to use them, we have the resources to help. Get information and guides to help you find and use NASA Earth science data, services, and tools.</p>
# <div class="align-left">
# <div class="field field--name-field-media-image field--type-image field--label-visually_hidden">
# <div class="field__label visually-hidden">Image</div>
# <div class="field__item">
# <a aria-controls="colorbox" aria-label='{"title":"Earthdata - Learn","alt":"Learn navigation graphic - an illustration of 3 students."}' class="colorbox" data-cbox-img-attrs='{"title":"Earthdata - Learn","alt":"Learn navigation graphic - an illustration of 3 students."}' data-colorbox-gallery="gallery-image-44817-GWyOcHOeV7k" href="https://www.earthdata.nasa.gov/s3fs-public/2021-12/learn-nav-image.png?VersionId=aWb2AOrq0TWA1S.blcAnbck4BKhZxDMR" role="button" title=""><img alt="Learn navigation graphic - an illustration of 3 students." height="162" loading="lazy" src="/s3fs-public/2021-12/learn-nav-image.png?VersionId=aWb2AOrq0TWA1S.blcAnbck4BKhZxDMR" title="Earthdata - Learn" typeof="foaf:Image" width="350"/></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="tb-megamenu-column span4 mega-col-nav" data-class="" data-hidewcol="" data-width="4" id="tb-megamenu-column-18">
# <div class="tb-megamenu-column-inner mega-inner clearfix">
# <ul class="tb-megamenu-subnav mega-nav level-1 items-6" role="list">
# <li aria-level="2" class="tb-megamenu-item level-2 mega" data-alignsub="" data-caption="" data-class="" data-group="0" data-hidesub="0" data-hidewcol="0" data-id="menu_link_content:c674fd3f-75e5-4276-b864-1e4b7a722bf9" data-label="" data-level="2" data-type="menu_item" data-xicon="">
# <a href="/learn/get-started">
#           Get Started
#           </a>
# </li>
# <li aria-level="2" class="tb-megamenu-item level-2 mega" data-alignsub="" data-caption="" data-class="" data-group="0" data-hidesub="0" data-hidewcol="0" data-id="menu_link_content:228de00c-5768-428c-b4ac-852af9d60aa2" data-label="" data-level="2" data-type="menu_item" data-xicon="">
# <a href="/learn/backgrounders">
#           Backgrounders
#           </a>
# </li>
# <li aria-level="2" class="tb-megamenu-item level-2 mega" data-alignsub="" data-caption="" data-class="" data-group="0" data-hidesub="0" data-hidewcol="0" data-id="menu_link_content:1870d0cf-68be-43fc-95b7-d110b332d932" data-label="" data-level="2" data-type="menu_item" data-xicon="">
# <a href="/learn/pathfinders">
#           Data Pathfinders
#           </a>
# </li>
# <li aria-level="2" class="tb-megamenu-item level-2 mega" data-alignsub="" data-caption="" data-class="" data-group="0" data-hidesub="0" data-hidewcol="0" data-id="menu_link_content:e8b8894a-2e36-4e7c-ae64-bb392353721b" data-label="" data-level="2" data-type="menu_item" data-xicon="">
# <a href="/learn/toolkits">
#           Data Toolkits
#           </a>
# </li>
# <li aria-level="2" class="tb-megamenu-item level-2 mega" data-alignsub="" data-caption="" data-class="" data-group="0" data-hidesub="0" data-hidewcol="0" data-id="menu_link_content:6a900c1d-5a1e-4e2a-9470-831a1d74d1e1" data-label="" data-level="2" data-type="menu_item" data-xicon="">
# <a href="/learn/webinars-and-tutorials">
#           Webinars and Tutorials
#           </a>
# </li>
# <li aria-level="2" class="tb-megamenu-item level-2 mega mega-group" data-alignsub="" data-caption="" data-class="" data-group="1" data-hidesub="0" data-hidewcol="0" data-id="menu_link_content:3a8d8a67-8289-4729-8de2-64b998606bb8" data-label="" data-level="2" data-type="menu_item" data-xicon="">
# <span aria-expanded="false" class="mega-group-title tb-megamenu-no-link" tabindex="0">
#           Data Stories
#           </span>
# <div class="tb-megamenu-submenu mega-group-ct nav-child" data-class="" data-fullwidthtarget="" data-pixelsorfullwidth="0" data-width="" role="list">
# <div class="mega-dropdown-inner container">
# <div class="tb-megamenu-row row-fluid">
# <div class="tb-megamenu-column mega-col-nav col-md-3 col-lg-3 col-xl-12" data-class="" data-hidewcol="0" id="tb-megamenu-column-19">
# <div class="tb-megamenu-column-inner mega-inner clearfix">
# <ul class="tb-megamenu-subnav mega-nav level-2 items-3" role="list">
# <li aria-level="3" class="tb-megamenu-item level-3 mega" data-alignsub="" data-caption="" data-class="" data-group="0" data-hidesub="0" data-hidewcol="0" data-id="menu_link_content:01b7c65d-efbf-4654-a193-a9798980711f" data-label="" data-level="3" data-type="menu_item" data-xicon="">
# <a href="/learn/articles">
#           Articles
#           </a>
# </li>
# <li aria-level="3" class="tb-megamenu-item level-3 mega" data-alignsub="" data-caption="" data-class="" data-group="0" data-hidesub="0" data-hidewcol="0" data-id="menu_link_content:611b42c5-cad5-41c7-88b6-f84a226cc81c" data-label="" data-level="3" data-type="menu_item" data-xicon="">
# <a href="/learn/data-chat">
#           Data Chats
#           </a>
# </li>
# <li aria-level="3" class="tb-megamenu-item level-3 mega" data-alignsub="" data-caption="" data-class="" data-group="0" data-hidesub="0" data-hidewcol="0" data-id="menu_link_content:00cf2ce8-e9d7-4c56-9de8-5f8a384b5f03" data-label="" data-level="3" data-type="menu_item" data-xicon="">
# <a href="/learn/data-user-profiles">
#           Data User Profiles
#           </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li aria-level="1" class="tb-megamenu-item level-1 mega mega-align-justify dropdown active active-trail" data-alignsub="justify" data-caption="" data-class="" data-group="0" data-hidesub="0" data-hidewcol="0" data-id="menu_link_content:60df74fd-fb45-4cdc-9aa4-280b5d25f756" data-label="" data-level="1" data-type="menu_item" data-xicon="">
# <a aria-expanded="false" class="dropdown-toggle active-trail" href="/engage">
#           Engage
#           </a>
# <div class="tb-megamenu-submenu dropdown-menu mega-dropdown-menu nav-child fullwidth" data-class="" data-fullwidthtarget="#navbar-main" data-pixelsorfullwidth="1" data-width="" fullwidth-target="#navbar-main" role="list">
# <div class="mega-dropdown-inner container">
# <div class="tb-megamenu-row row-fluid">
# <div class="tb-megamenu-column span4 mega-col-nav" data-class="" data-hidewcol="0" data-showblocktitle="1" data-width="4" id="tb-megamenu-column-20">
# <div class="tb-megamenu-column-inner mega-inner clearfix">
# <div class="tb-block tb-megamenu-block" data-block="navengagedescription" data-type="block">
# <div class="block-inner">
# <div class="block block-block-content block-block-content18724f09-a760-46ae-9e87-a41cd22a9395" data-block-plugin-id="block_content:18724f09-a760-46ae-9e87-a41cd22a9395" id="block-block-content18724f09-a760-46ae-9e87-a41cd22a9395">
# <div class="content">
# <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item"><h2>Engage</h2>
# <p>We provide a variety of ways for Earth scientists to collaborate with NASA.</p>
# <div class="align-left">
# <div class="field field--name-field-media-image field--type-image field--label-visually_hidden">
# <div class="field__label visually-hidden">Image</div>
# <div class="field__item">
# <a aria-controls="colorbox" aria-label='{"title":"Earthdata - Engage","alt":"Engage navigation graphic - an illustration of multiple data users/consumers."}' class="colorbox" data-cbox-img-attrs='{"title":"Earthdata - Engage","alt":"Engage navigation graphic - an illustration of multiple data users/consumers."}' data-colorbox-gallery="gallery-image-44818-GWyOcHOeV7k" href="https://www.earthdata.nasa.gov/s3fs-public/2021-12/engage-nav-image.png?VersionId=Iymn0s3WOLjfRuzdBAm8b14rgIvEoAxK" role="button" title=""><img alt="Engage navigation graphic - an illustration of multiple data users/consumers." height="162" loading="lazy" src="/s3fs-public/2021-12/engage-nav-image.png?VersionId=Iymn0s3WOLjfRuzdBAm8b14rgIvEoAxK" title="Earthdata - Engage" typeof="foaf:Image" width="350"/></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="tb-megamenu-column span4 mega-col-nav" data-class="" data-hidewcol="" data-width="4" id="tb-megamenu-column-21">
# <div class="tb-megamenu-column-inner mega-inner clearfix">
# <ul class="tb-megamenu-subnav mega-nav level-1 items-2" role="list">
# <li aria-level="2" class="tb-megamenu-item level-2 mega" data-alignsub="" data-caption="" data-class="" data-group="0" data-hidesub="0" data-hidewcol="0" data-id="menu_link_content:47dff9e7-1948-47f7-b439-03153b899d68" data-label="" data-level="2" data-type="menu_item" data-xicon="">
# <a href="/engage/data-management-guidance">
#           Data Management Guidance
#           </a>
# </li>
# <li aria-level="2" class="tb-megamenu-item level-2 mega mega-align-left mega-group active active-trail" data-alignsub="left" data-caption="" data-class="" data-group="1" data-hidesub="0" data-hidewcol="0" data-id="menu_link_content:f11a75f9-8159-45a1-a783-1ed7d9c0a299" data-label="" data-level="2" data-type="menu_item" data-xicon="">
# <a aria-expanded="false" class="mega-group-title active-trail" href="/engage/open-data-services-and-software">
#           Open Data, Services, and Software Policies
#           </a>
# <div class="tb-megamenu-submenu mega-group-ct nav-child" data-class="" data-fullwidthtarget="" data-pixelsorfullwidth="0" data-width="" role="list">
# <div class="mega-dropdown-inner container">
# <div class="tb-megamenu-row row-fluid">
# <div class="tb-megamenu-column mega-col-nav col-md-3 col-lg-3 col-xl-12" data-class="" data-hidewcol="0" id="tb-megamenu-column-22">
# <div class="tb-megamenu-column-inner mega-inner clearfix">
# <ul class="tb-megamenu-subnav mega-nav level-2 items-3" role="list">
# <li aria-level="3" class="tb-megamenu-item level-3 mega" data-alignsub="" data-caption="" data-class="" data-group="0" data-hidesub="0" data-hidewcol="0" data-id="menu_link_content:b6911a81-4888-472f-afb2-b14e2dd1c42e" data-label="" data-level="3" data-type="menu_item" data-xicon="">
# <a href="/engage/open-data-services-and-software/esds-open-source-policy">
#           Open Source Software Policy
#           </a>
# </li>
# <li aria-level="3" class="tb-megamenu-item level-3 mega active active-trail" data-alignsub="" data-caption="" data-class="" data-group="0" data-hidesub="0" data-hidewcol="0" data-id="menu_link_content:a93fd2a7-6898-4f5a-80a6-cfe01c85109f" data-label="" data-level="3" data-type="menu_item" data-xicon="">
# <a class="active-trail" href="/engage/open-data-services-and-software/api">
#           Application Programming Interfaces (APIs)
#           </a>
# </li>
# <li aria-level="3" class="tb-megamenu-item level-3 mega" data-alignsub="" data-caption="" data-class="" data-group="0" data-hidesub="0" data-hidewcol="0" data-id="menu_link_content:b0583430-f660-4fa5-83ef-d634f6124544" data-label="" data-level="3" data-type="menu_item" data-xicon="">
# <a href="/engage/ecc">
#           Earthdata Code Collaborative (ECC)
#           </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="tb-megamenu-column span4 mega-col-nav" data-class="" data-hidewcol="" data-width="4" id="tb-megamenu-column-23">
# <div class="tb-megamenu-column-inner mega-inner clearfix">
# <ul class="tb-megamenu-subnav mega-nav level-1 items-4" role="list">
# <li aria-level="2" class="tb-megamenu-item level-2 mega mega-align-left mega-group" data-alignsub="left" data-caption="" data-class="" data-group="1" data-hidesub="0" data-hidewcol="0" data-id="menu_link_content:37d12727-59cd-4af5-8fa5-49f3ea012002" data-label="" data-level="2" data-type="menu_item" data-xicon="">
# <a aria-expanded="false" class="mega-group-title" href="/engage/standards">
#           Standards
#           </a>
# <div class="tb-megamenu-submenu mega-group-ct nav-child" data-class="" data-fullwidthtarget="" data-pixelsorfullwidth="0" data-width="" role="list">
# <div class="mega-dropdown-inner container">
# <div class="tb-megamenu-row row-fluid">
# <div class="tb-megamenu-column mega-col-nav col-md-3 col-lg-3 col-xl-12" data-class="" data-hidewcol="0" id="tb-megamenu-column-24">
# <div class="tb-megamenu-column-inner mega-inner clearfix">
# <ul class="tb-megamenu-subnav mega-nav level-2 items-3" role="list">
# <li aria-level="3" class="tb-megamenu-item level-3 mega" data-alignsub="" data-caption="" data-class="" data-group="0" data-hidesub="0" data-hidewcol="0" data-id="menu_link_content:251a27f9-76e2-49db-bd15-3db32cb44424" data-label="" data-level="3" data-type="menu_item" data-xicon="">
# <a href="/esdis/eso/standards-and-references">
#           Data Standards and Requirements
#           </a>
# </li>
# <li aria-level="3" class="tb-megamenu-item level-3 mega" data-alignsub="" data-caption="" data-class="" data-group="0" data-hidesub="0" data-hidewcol="0" data-id="menu_link_content:9b30fb90-0e3d-4246-b4b7-32d338587cc7" data-label="" data-level="3" data-type="menu_item" data-xicon="">
# <a href="/use-data/data-use-policy">
#           Data Use Policy
#           </a>
# </li>
# <li aria-level="3" class="tb-megamenu-item level-3 mega" data-alignsub="" data-caption="" data-class="" data-group="0" data-hidesub="0" data-hidewcol="0" data-id="menu_link_content:e3f00399-3429-4b5d-8542-7b9692c5c63c" data-label="" data-level="3" data-type="menu_item" data-xicon="">
# <a href="/use-data/data-citations-acknowledgements">
#           Data Citations and Acknowledgements
#           </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li aria-level="2" class="tb-megamenu-item level-2 mega" data-alignsub="" data-caption="" data-class="" data-group="0" data-hidesub="0" data-hidewcol="0" data-id="menu_link_content:311e472a-c75f-43ef-ac8a-2ef48b78432c" data-label="" data-level="2" data-type="menu_item" data-xicon="">
# <a href="/engage/new-missions">
#           Adding New Data to EOSDIS
#           </a>
# </li>
# <li aria-level="2" class="tb-megamenu-item level-2 mega" data-alignsub="" data-caption="" data-class="" data-group="0" data-hidesub="0" data-hidewcol="0" data-id="menu_link_content:398722dd-5664-4431-8506-1015b239c992" data-label="" data-level="2" data-type="menu_item" data-xicon="">
# <a href="/engage/esds-public-private-partnerships">
#           Public &amp; Private Partnerships
#           </a>
# </li>
# <li aria-level="2" class="tb-megamenu-item level-2 mega" data-alignsub="" data-caption="" data-class="" data-group="0" data-hidesub="0" data-hidewcol="0" data-id="menu_link_content:b246f476-e9b6-488d-a158-34c77c9482ed" data-label="" data-level="2" data-type="menu_item" data-xicon="">
# <a href="/engage/memberships-and-affiliations">
#           Memberships &amp; Affiliations
#           </a>
# ...
# <div><a href="/engage/esds-public-private-partnerships">Public/Private Partnerships</a></div>
# <div><a href="/engage/memberships-and-affiliations">Members and Affiliations</a></div>
# </div>
# <div class="col-3">
# <div class="heading"><a href="/about">About</a></div>
# <div><a href="/esds">ESDS Program</a></div>
# <div class="child"><a href="/esds/esds-program-components">ESDS Program Components</a></div>
# <div class="child"><a href="/esds/csda">Commercial Smallsat Data Acquisition (CSDA) Program</a></div>
# <div class="child"><a href="/esds/competitive-programs">Competitive Programs</a></div>
# <div class="child"><a href="/esds/impact">Interagency Implementation and Advanced Concepts Team (IMPACT)</a></div>
# <div><a href="/esdis">ESDIS Project</a></div>
# <div class="child"><a href="https://doclib.eosdis.nasa.gov/ords/f?p=104">ESDIS Project Library</a></div>
# <div class="child"><a href="https://ops1-cm.ems.eosdis.nasa.gov/cm2/">COMET (login required)</a></div>
# <div><a href="/eosdis">EOSDIS</a></div>
# <div class="child"><a href="/daacs">DAACs</a></div>
# <div class="child"><a href="/eosdis/system-performance">System Performance and Metrics</a></div>
# <div class="child"><a href="">System Components</a></div>
# <div class="child"><a href="/eosdis/data-system-interfaces">Data System Interfaces</a></div>
# </div>
# </div>
# <div class="py-3 my-auto d-none d-sm-none d-md-block">
# <hr/></div>
# <div class="footer-mobile d-block d-sm-block d-md-none">
# <div class="footer-social-title my-auto">More From Earthdata</div>
# <ul>
# <li><a href="/contact">Contact Us</a></li>
# <li><a href="https://forum.earthdata.nasa.gov/" target="_blank">Earthdata Forum</a></li>
# <li><a href="/learn/earthdata-user-community-forums">Community Forums</a></li>
# <li><a href="/support">Support</a></li>
# </ul>
# </div>
# <div class="compliance">
# <div class="footer-social-title my-auto d-block d-sm-block d-md-none">Related Links</div>
# <div class="text-md-center justify-content-center justify-content-sm-center justify-content-md-start justify-content-lg-center d-md-flex">
# <ul>
# <li class="d-none d-sm-none d-md-inline-block">NASA Official: Cerese Albers</li>
# <li><a href="https://www.nasa.gov/about/highlights/HP_Privacy.html" target="_blank">Web Privacy Policy</a></li>
# <li><a href="/engage/open-data-services-and-software/data-information-policy">Data and Information Policy</a></li>
# <li><a href="https://www.nasa.gov/audience/formedia/features/communication_policy.html" target="_blank">Communications Policy</a></li>
# <li><a href="https://www.nasa.gov/FOIA/index.html" target="_blank">Freedom of Information Act</a></li>
# <li><a href="https://www.usa.gov/" target="_blank">USA.gov</a></li>
# <li><a href="/sitemap.xml">Sitemap</a></li>
# </ul>
# </div>
# <div class="my-auto d-block d-sm-block d-md-none">
# <hr/></div>
# <div class="d-block d-sm-block d-md-none light-blue-text fw-bold">NASA Official: Cerese Albers</div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="region region-footer-second">
# <div class="block block-block-content block-block-content968ad096-7934-42ed-975c-2977c99332fe" data-block-plugin-id="block_content:968ad096-7934-42ed-975c-2977c99332fe" id="block-subfooter">
# <div class="content">
# </div>
# </div>
# </section>
# </div>
# </div>
# </div>
# </footer>
# </div>
# </div>
# </div>
# </div>
# <script src="/s3fs-public/js/js_qnBhz36fVpMPXctWcF6hYP0MjE67yiqA_Q_M2Oybods.js?VersionId=KnIsx01lyjGvrSFin84GtQlA5lbx4d1H"></script>
# <script async="" src="https://static.addtoany.com/menu/page.js"></script>
# <script src="/s3fs-public/js/js_azBlJXrDcGXIbRw5nR23VW3mbRyMoXfBj0GbLtj4q3Q.js?VersionId=Qy6EFzCCgSqi8MavqByiGmxoMUx.0rMF"></script>
# <script src="https://unpkg.com/slide-element@2/dist/index.umd.js"></script>
# <script src="/s3fs-public/js/js_Gy3gvLNpAHhbI87I_hO4jdk-icwEPj7cxVN9Nfkdhlc.js?VersionId=NtRmynjbSe5IF.Qcds74AucwaEqzhv6f"></script>
# <script async="" defer="" src="//static.ctctcdn.com/js/signup-form-widget/current/signup-form-widget.min.js"></script>
# </body> <head>
# <meta charset="utf-8"/>
# <link href="https://www.earthdata.nasa.gov/engage/open-data-services-and-software/api" rel="canonical"/>
# <meta content="NASA, Earth, Space, Science, Satellite, Satellite Photo, DAAC, ECHO," name="news_keywords"/>
# <link href="/s3fs-public/imported/ed-default-thumbnail.png?VersionId=s6gtprOuEbxsFzKCdQzSodPomZ4.NFzX" rel="image_src"/>
# <meta content="general" name="rating"/>
# <meta content="no-referrer-when-downgrade" name="referrer"/>
# <meta content="NASA's Earthdata Developer Portal is for application developers who wish to build applications that search, access, and browse EOSDIS Earth science data." name="description"/>
# <meta content="NASA's Earthdata Developer Portal is for application developers who wish to build applications that search, access, and browse EOSDIS Earth science data." name="abstract"/>
# <meta content=", , ," name="keywords"/>
# <meta content="Earthdata Developer Portal | Earthdata" name="dcterms.title"/>
# <meta content="Earth Data" name="dcterms.subject"/>
# <meta content="NASA's Earthdata Developer Portal is for application developers who wish to build applications that search, access, and browse EOSDIS Earth science data." name="dcterms.description"/>
# <meta content="Earth Science Data Systems, NASA" name="dcterms.publisher"/>
# <meta content="Earth Science Data Systems, NASA" name="dcterms.contributor"/>
# <meta content="2015-04-06" name="dcterms.date"/>
# <meta content="Basic Page" name="dcterms.type"/>
# <meta content="text/html" name="dcterms.format"/>
# <meta content="/engage/open-data-services-and-software/api" name="dcterms.identifier"/>
# <meta content="Earthdata" property="og:site_name"/>
# <meta content="Basic Page" property="og:type"/>
# <meta content="https://www.earthdata.nasa.gov/engage/open-data-services-and-software/api" property="og:url"/>
# <meta content="Earthdata Developer Portal | Earthdata" property="og:title"/>
# <meta content="NASA's Earthdata Developer Portal is for application developers who wish to build applications that search, access, and browse EOSDIS Earth science data." property="og:description"/>
# <meta content="https://www.earthdata.nasa.gov/s3fs-public/imported/ed-default-thumbnail.png?VersionId=s6gtprOuEbxsFzKCdQzSodPomZ4.NFzX" property="og:image"/>
# <meta content="Placeholder image" property="og:image:alt"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="@NASAEarthData" name="twitter:site"/>
# <meta content="NASA's Earthdata Developer Portal is for application developers who wish to build applications that search, access, and browse EOSDIS Earth science data." name="twitter:description"/>
# <meta content="Earthdata Developer Portal | Earthdata" name="twitter:title"/>
# <meta content="https://www.earthdata.nasa.gov/engage/open-data-services-and-software/api" name="twitter:url"/>
# <meta content="Placeholder image" name="twitter:image:alt"/>
# <meta content="https://www.earthdata.nasa.gov/s3fs-public/imported/ed-default-thumbnail.png?VersionId=s6gtprOuEbxsFzKCdQzSodPomZ4.NFzX" name="twitter:image"/>
# <meta content="Drupal 9 (https://www.drupal.org)" name="Generator"/>
# <meta content="width" name="MobileOptimized"/>
# <meta content="true" name="HandheldFriendly"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <script type="application/ld+json">{
#     "@context": "https://schema.org",
#     "@graph": [
#         {
#             "@type": "Article",
#             "headline": "Earthdata Developer Portal",
#             "name": "Earthdata Developer Portal",
#             "about": [],
#             "description": "NASA\u0027s Earthdata Developer Portal is for application developers who wish to build applications that search, access, and browse EOSDIS Earth science data.",
#             "image": {
#                 "@type": "ImageObject",
#                 "representativeOfPage": "True",
#                 "url": "/s3fs-public/imported/ed-default-thumbnail.png?VersionId=s6gtprOuEbxsFzKCdQzSodPomZ4.NFzX"
#             },
#             "datePublished": "2015-04-06",
#             "dateModified": "2022-11-03",
#             "isAccessibleForFree": "True",
#             "author": {
#                 "@type": "Person",
#                 "@id": "jblumenf",
#                 "name": "Josh Blumenfeld",
#                 "logo": {
#                     "@type": "ImageObject",
#                     "representativeOfPage": "False",
#                     "url": "https://www.earthdata.nasa.gov/s3fs-public/styles/thumbnail/public/pictures/2021-11/IMG_0113.jpg?VersionId=iGMDdXldNqf3.YOHenX7ZDHWroq6qb3w\u0026itok=pKu2soho"
#                 }
#             },
#             "publisher": {
#                 "@type": "GovernmentOrganization",
#                 "@id": "https://earthdata.nasa.gov/",
#                 "name": [
#                     "Earth Science Data Systems",
#                     "NASA"
#                 ],
#                 "url": "https://earthdata.nasa.gov/",
#                 "logo": {
#                     "@type": "ImageObject",
#                     "representativeOfPage": "True",
#                     "url": "https://www.earthdata.nasa.gov/s3fs-public/earthdata-oaos-logo-hover.png",
#                     "width": "256px",
#                     "height": "50px"
#                 }
#             }
#         },
#         {
#             "@type": "WebSite",
#             "@id": "https://earthdata.nasa.gov/",
#             "name": "Earthdata",
#             "url": "https://earthdata.nasa.gov/",
#             "potentialAction": {
#                 "@type": "SearchAction",
#                 "target": {
#                     "@type": "EntryPoint",
#                     "urlTemplate": "https://earthdata.nasa.gov/search?keys={search_term_string}",
#                     "inLanguage": "en-US"
#                 },
#                 "result": {
#                     "@type": "GovernmentOrganization",
#                     "@id": "https://earthdata.nasa.gov/",
#                     "name": [
#                         "Earth Science Data Systems",
#                         "NASA"
#                     ],
#                     "url": "https://earthdata.nasa.gov/"
#                 },
#                 "query": "https://www.earthdata.nasa.gov/search?keys={search_term_string}",
#                 "query-input": "required name=search_term_string"
#             },
#             "publisher": {
#                 "@type": "GovernmentOffice",
#                 "@id": "https://earthdata.nasa.gov/",
#                 "name": [
#                     "Earth Science Data Systems",
#                     "NASA"
#                 ],
#                 "url": "https://earthdata.nasa.gov/",
#                 "logo": {
#                     "@type": "ImageObject",
#                     "representativeOfPage": "True",
#                     "url": "https://www.earthdata.nasa.gov/s3fs-public/earthdata-oaos-logo-hover.png",
#                     "width": "265px",
#                     "height": "50px"
#                 }
#             },
#             "inLanguage": "en-US"
#         }
#     ]
# }</script>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <script type="application/ld+json">{
#           "@context": "https://schema.org",
#           "@type": "BreadcrumbList",
#           "itemListElement": [{
#             "@type": "ListItem",
#             "position": "1",
#             "name": "Earthdata",
#             "item": "https://www.earthdata.nasa.gov/"
#           },{
#             "@type": "ListItem",
#             "position": "2",
#             "name": "Engage",
#             "item": "https://www.earthdata.nasa.gov/engage"
#           },{
#             "@type": "ListItem",
#             "position": "3",
#             "name": "Open Data, Services, and Software Policies",
#             "item": "https://www.earthdata.nasa.gov/engage/open-data-services-and-software"
#           },{
#               "@type": "ListItem",
#               "position": "4",
#               "name": "Earthdata Developer Portal"
#             }]}</script>
# <link href="/sites/default/files/nasa-meatball.png" rel="icon" type="image/png"/>
# <script>window.a2a_config=window.a2a_config||{};a2a_config.callbacks=[];a2a_config.overlays=[];a2a_config.templates={};a2a_config.icon_color = "#22b463";</script>
# <title>Earthdata Developer Portal | Earthdata</title>
# <link href="/s3fs-public/css/css_-O9N4gHFGe4EQS3BQLsezTRP9kHSyVAu2wmQ5L6O-Ug.css?VersionId=RTrKL3gXmHUFO0yx82KSHpvPErrjxPWa" media="all" rel="stylesheet"/>
# <link href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.3.0/css/font-awesome.min.css" media="all" rel="stylesheet"/>
# <link href="/s3fs-public/css/css_XtSvlgbQYjcDoeApsmyGPrq_13D4jgFxUbmjux3Cnrs.css?VersionId=HsTnZoCqE8TsBpA8uAEcp79Dwch.2_Q0" media="all" rel="stylesheet"/>
# <link href="/s3fs-public/css/css_O1xqJyUcqlIHj5lamlINh3kOdjGjxZzm9LoUTcVtbXo.css?VersionId=iD6uPtlWcrgRP3IiJzjZ32YQK1gvZhvQ" media="all" rel="stylesheet"/>
# <link href="//use.fontawesome.com/releases/v5.13.0/css/all.css" media="all" rel="stylesheet"/>
# <link href="/s3fs-public/css/css_Z0EWytWlrXjitsepirFcFc9l-ewB8O2kdxzYGsz4bDQ.css?VersionId=o3d.vtX.fZLc1.6NpJwJv4JhTaB6zT2d" media="all" rel="stylesheet"/>
# <link href="//fonts.googleapis.com/css2?family=Open+Sans:ital,wght@0,300;0,400;0,600;0,700;0,800;1,300;1,400;1,600;1,700;1,800&amp;display=swap" media="all" rel="stylesheet"/>
# <link href="/s3fs-public/css/css_dW8MKPHWLPZui6ms4gBw7I9kyIWmqXhlvGM3oU8Sw3A.css?VersionId=eMqn.y2gF5VeaJXHxiPcc6lyZYH84u1t" media="all" rel="stylesheet"/>
# <script data-drupal-selector="drupal-settings-json" type="application/json">{"path":{"baseUrl":"\/","scriptPath":null,"pathPrefix":"","currentPath":"node\/43","currentPathIsAdmin":false,"isFront":false,"currentLanguage":"en"},"pluralDelimiter":"\u0003","suppressDeprecationErrors":true,"data":{"extlink":{"extTarget":false,"extTargetNoOverride":false,"extNofollow":false,"extNoreferrer":true,"extFollowNoOverride":false,"extClass":"ext","extLabel":"(link is external)","extImgClass":false,"extSubdomains":true,"extExclude":"","extInclude":"","extCssExclude":".node--type-job-opening .field--name-field-job-url","extCssExplicit":"","extAlert":true,"extAlertText":"This link will take you to an external web site. We are not responsible for their content.","mailtoClass":"mailto","mailtoLabel":"(link sends email)","extUseFontAwesome":false,"extIconPlacement":"append","extFaLinkClasses":"fa fa-external-link","extFaMailtoClasses":"fa fa-envelope-o","whitelistedDomains":[".*\\earthdata.nasa.gov","firms.modaps.eosdis.nasa.gov","d10a3v3te7tlzl.cloudfront.net","d2cw1xlrxl8h8g.cloudfront.net","d371hv6zcxz9vm.cloudfront.net",".*\\cloudfront.net","nasaenterprise.webex.com"]}},"ckeditorAccordion":{"accordionStyle":{"collapseAll":1,"keepRowsOpen":1}},"collapsiblock":{"active_pages":false,"slide_speed":200,"cookie_lifetime":null},"TBMegaMenu":{"TBElementsCounter":{"column":29},"theme":"earthdata"},"colorbox":{"opacity":"0.85","current":"{current} of {total}","previous":"\u00ab Prev","next":"Next \u00bb","close":"Close","maxWidth":"98%","maxHeight":"98%","fixed":true,"mobiledetect":false,"mobiledevicewidth":"480px"},"user":{"uid":0,"permissionsHash":"9f96380f838406ed8b8f43f34118025525e1eacaed9bcd1327470113de0d27cb"}}</script>
# <script src="/s3fs-public/js/js_OjTLiimmGzO8fQT0OdX2VuzljtqLW1C6POMpz9y3EBU.js?VersionId=Smji5H4cWx8JOXNcGtRKtch7l3U8o0mG"></script>
# <script async="" src="//www.googletagmanager.com/gtag/js?id=GTM-WNP7MLF"></script>
# <script async="" src="//script.crazyegg.com/pages/scripts/0013/2090.js"></script>
# <script id="_fed_an_ua_tag" src="//dap.digitalgov.gov/Universal-Federated-Analytics-Min.js?agency=NASA&amp;subagency=GSFC&amp;dclink=true"></script>
# <meta content="613" name="orgcode"/>
# <meta content="Kevin Murphy" name="rno"/>
# <meta content="Kevin Ward" name="content-owner"/>
# <meta content="Goran Halusa" name="webmaster"/>
# <meta content="The Earth Observing System Data and Information System
#        is a key core capability in NASA’s Earth Science Data Systems Program. It provides end-to-end
#        capabilities for managing NASA’s Earth science data from various sources—satellites, aircraft,
#        field measurements, and various other programs." name="description"/>
# </head>

# %%
import requests
from bs4 import BeautifulSoup

# Make a request
page = requests.get(
    "https://www.earthdata.nasa.gov/engage/open-data-services-and-software/api")
soup = BeautifulSoup(page.content, 'html.parser')

# Extract title of page
page_title = soup.title

# Extract body of page
page_body = soup.body

# Extract head of page
page_head = soup.head

# print the result
print(page_title, page_head)
# Out:
# <title>Earthdata Developer Portal | Earthdata</title> <head>
# <meta charset="utf-8"/>
# <link href="https://www.earthdata.nasa.gov/engage/open-data-services-and-software/api" rel="canonical"/>
# <meta content="NASA, Earth, Space, Science, Satellite, Satellite Photo, DAAC, ECHO," name="news_keywords"/>
# <link href="/s3fs-public/imported/ed-default-thumbnail.png?VersionId=s6gtprOuEbxsFzKCdQzSodPomZ4.NFzX" rel="image_src"/>
# <meta content="general" name="rating"/>
# <meta content="no-referrer-when-downgrade" name="referrer"/>
# <meta content="NASA's Earthdata Developer Portal is for application developers who wish to build applications that search, access, and browse EOSDIS Earth science data." name="description"/>
# <meta content="NASA's Earthdata Developer Portal is for application developers who wish to build applications that search, access, and browse EOSDIS Earth science data." name="abstract"/>
# <meta content=", , ," name="keywords"/>
# <meta content="Earthdata Developer Portal | Earthdata" name="dcterms.title"/>
# <meta content="Earth Data" name="dcterms.subject"/>
# <meta content="NASA's Earthdata Developer Portal is for application developers who wish to build applications that search, access, and browse EOSDIS Earth science data." name="dcterms.description"/>
# <meta content="Earth Science Data Systems, NASA" name="dcterms.publisher"/>
# <meta content="Earth Science Data Systems, NASA" name="dcterms.contributor"/>
# <meta content="2015-04-06" name="dcterms.date"/>
# <meta content="Basic Page" name="dcterms.type"/>
# <meta content="text/html" name="dcterms.format"/>
# <meta content="/engage/open-data-services-and-software/api" name="dcterms.identifier"/>
# <meta content="Earthdata" property="og:site_name"/>
# <meta content="Basic Page" property="og:type"/>
# <meta content="https://www.earthdata.nasa.gov/engage/open-data-services-and-software/api" property="og:url"/>
# <meta content="Earthdata Developer Portal | Earthdata" property="og:title"/>
# <meta content="NASA's Earthdata Developer Portal is for application developers who wish to build applications that search, access, and browse EOSDIS Earth science data." property="og:description"/>
# <meta content="https://www.earthdata.nasa.gov/s3fs-public/imported/ed-default-thumbnail.png?VersionId=s6gtprOuEbxsFzKCdQzSodPomZ4.NFzX" property="og:image"/>
# <meta content="Placeholder image" property="og:image:alt"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="@NASAEarthData" name="twitter:site"/>
# <meta content="NASA's Earthdata Developer Portal is for application developers who wish to build applications that search, access, and browse EOSDIS Earth science data." name="twitter:description"/>
# <meta content="Earthdata Developer Portal | Earthdata" name="twitter:title"/>
# <meta content="https://www.earthdata.nasa.gov/engage/open-data-services-and-software/api" name="twitter:url"/>
# <meta content="Placeholder image" name="twitter:image:alt"/>
# <meta content="https://www.earthdata.nasa.gov/s3fs-public/imported/ed-default-thumbnail.png?VersionId=s6gtprOuEbxsFzKCdQzSodPomZ4.NFzX" name="twitter:image"/>
# <meta content="Drupal 9 (https://www.drupal.org)" name="Generator"/>
# <meta content="width" name="MobileOptimized"/>
# <meta content="true" name="HandheldFriendly"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <script type="application/ld+json">{
#     "@context": "https://schema.org",
#     "@graph": [
#         {
#             "@type": "Article",
#             "headline": "Earthdata Developer Portal",
#             "name": "Earthdata Developer Portal",
#             "about": [],
#             "description": "NASA\u0027s Earthdata Developer Portal is for application developers who wish to build applications that search, access, and browse EOSDIS Earth science data.",
#             "image": {
#                 "@type": "ImageObject",
#                 "representativeOfPage": "True",
#                 "url": "/s3fs-public/imported/ed-default-thumbnail.png?VersionId=s6gtprOuEbxsFzKCdQzSodPomZ4.NFzX"
#             },
#             "datePublished": "2015-04-06",
#             "dateModified": "2022-11-03",
#             "isAccessibleForFree": "True",
#             "author": {
#                 "@type": "Person",
#                 "@id": "jblumenf",
#                 "name": "Josh Blumenfeld",
#                 "logo": {
#                     "@type": "ImageObject",
#                     "representativeOfPage": "False",
#                     "url": "https://www.earthdata.nasa.gov/s3fs-public/styles/thumbnail/public/pictures/2021-11/IMG_0113.jpg?VersionId=iGMDdXldNqf3.YOHenX7ZDHWroq6qb3w\u0026itok=pKu2soho"
#                 }
#             },
#             "publisher": {
#                 "@type": "GovernmentOrganization",
#                 "@id": "https://earthdata.nasa.gov/",
#                 "name": [
#                     "Earth Science Data Systems",
#                     "NASA"
#                 ],
#                 "url": "https://earthdata.nasa.gov/",
#                 "logo": {
#                     "@type": "ImageObject",
#                     "representativeOfPage": "True",
#                     "url": "https://www.earthdata.nasa.gov/s3fs-public/earthdata-oaos-logo-hover.png",
#                     "width": "256px",
#                     "height": "50px"
#                 }
#             }
#         },
#         {
#             "@type": "WebSite",
#             "@id": "https://earthdata.nasa.gov/",
#             "name": "Earthdata",
#             "url": "https://earthdata.nasa.gov/",
#             "potentialAction": {
#                 "@type": "SearchAction",
#                 "target": {
#                     "@type": "EntryPoint",
#                     "urlTemplate": "https://earthdata.nasa.gov/search?keys={search_term_string}",
#                     "inLanguage": "en-US"
#                 },
#                 "result": {
#                     "@type": "GovernmentOrganization",
#                     "@id": "https://earthdata.nasa.gov/",
#                     "name": [
#                         "Earth Science Data Systems",
#                         "NASA"
#                     ],
#                     "url": "https://earthdata.nasa.gov/"
#                 },
#                 "query": "https://www.earthdata.nasa.gov/search?keys={search_term_string}",
#                 "query-input": "required name=search_term_string"
#             },
#             "publisher": {
#                 "@type": "GovernmentOffice",
#                 "@id": "https://earthdata.nasa.gov/",
#                 "name": [
#                     "Earth Science Data Systems",
#                     "NASA"
#                 ],
#                 "url": "https://earthdata.nasa.gov/",
#                 "logo": {
#                     "@type": "ImageObject",
#                     "representativeOfPage": "True",
#                     "url": "https://www.earthdata.nasa.gov/s3fs-public/earthdata-oaos-logo-hover.png",
#                     "width": "265px",
#                     "height": "50px"
#                 }
#             },
#             "inLanguage": "en-US"
#         }
#     ]
# }</script>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <script type="application/ld+json">{
#           "@context": "https://schema.org",
#           "@type": "BreadcrumbList",
#           "itemListElement": [{
#             "@type": "ListItem",
#             "position": "1",
#             "name": "Earthdata",
#             "item": "https://www.earthdata.nasa.gov/"
#           },{
#             "@type": "ListItem",
#             "position": "2",
#             "name": "Engage",
#             "item": "https://www.earthdata.nasa.gov/engage"
#           },{
#             "@type": "ListItem",
#             "position": "3",
#             "name": "Open Data, Services, and Software Policies",
#             "item": "https://www.earthdata.nasa.gov/engage/open-data-services-and-software"
#           },{
#               "@type": "ListItem",
#               "position": "4",
#               "name": "Earthdata Developer Portal"
#             }]}</script>
# <link href="/sites/default/files/nasa-meatball.png" rel="icon" type="image/png"/>
# <script>window.a2a_config=window.a2a_config||{};a2a_config.callbacks=[];a2a_config.overlays=[];a2a_config.templates={};a2a_config.icon_color = "#22b463";</script>
# <title>Earthdata Developer Portal | Earthdata</title>
# <link href="/s3fs-public/css/css_-O9N4gHFGe4EQS3BQLsezTRP9kHSyVAu2wmQ5L6O-Ug.css?VersionId=RTrKL3gXmHUFO0yx82KSHpvPErrjxPWa" media="all" rel="stylesheet"/>
# <link href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.3.0/css/font-awesome.min.css" media="all" rel="stylesheet"/>
# <link href="/s3fs-public/css/css_XtSvlgbQYjcDoeApsmyGPrq_13D4jgFxUbmjux3Cnrs.css?VersionId=HsTnZoCqE8TsBpA8uAEcp79Dwch.2_Q0" media="all" rel="stylesheet"/>
# <link href="/s3fs-public/css/css_O1xqJyUcqlIHj5lamlINh3kOdjGjxZzm9LoUTcVtbXo.css?VersionId=iD6uPtlWcrgRP3IiJzjZ32YQK1gvZhvQ" media="all" rel="stylesheet"/>
# <link href="//use.fontawesome.com/releases/v5.13.0/css/all.css" media="all" rel="stylesheet"/>
# <link href="/s3fs-public/css/css_Z0EWytWlrXjitsepirFcFc9l-ewB8O2kdxzYGsz4bDQ.css?VersionId=o3d.vtX.fZLc1.6NpJwJv4JhTaB6zT2d" media="all" rel="stylesheet"/>
# <link href="//fonts.googleapis.com/css2?family=Open+Sans:ital,wght@0,300;0,400;0,600;0,700;0,800;1,300;1,400;1,600;1,700;1,800&amp;display=swap" media="all" rel="stylesheet"/>
# <link href="/s3fs-public/css/css_dW8MKPHWLPZui6ms4gBw7I9kyIWmqXhlvGM3oU8Sw3A.css?VersionId=eMqn.y2gF5VeaJXHxiPcc6lyZYH84u1t" media="all" rel="stylesheet"/>
# <script data-drupal-selector="drupal-settings-json" type="application/json">{"path":{"baseUrl":"\/","scriptPath":null,"pathPrefix":"","currentPath":"node\/43","currentPathIsAdmin":false,"isFront":false,"currentLanguage":"en"},"pluralDelimiter":"\u0003","suppressDeprecationErrors":true,"data":{"extlink":{"extTarget":false,"extTargetNoOverride":false,"extNofollow":false,"extNoreferrer":true,"extFollowNoOverride":false,"extClass":"ext","extLabel":"(link is external)","extImgClass":false,"extSubdomains":true,"extExclude":"","extInclude":"","extCssExclude":".node--type-job-opening .field--name-field-job-url","extCssExplicit":"","extAlert":true,"extAlertText":"This link will take you to an external web site. We are not responsible for their content.","mailtoClass":"mailto","mailtoLabel":"(link sends email)","extUseFontAwesome":false,"extIconPlacement":"append","extFaLinkClasses":"fa fa-external-link","extFaMailtoClasses":"fa fa-envelope-o","whitelistedDomains":[".*\\earthdata.nasa.gov","firms.modaps.eosdis.nasa.gov","d10a3v3te7tlzl.cloudfront.net","d2cw1xlrxl8h8g.cloudfront.net","d371hv6zcxz9vm.cloudfront.net",".*\\cloudfront.net","nasaenterprise.webex.com"]}},"ckeditorAccordion":{"accordionStyle":{"collapseAll":1,"keepRowsOpen":1}},"collapsiblock":{"active_pages":false,"slide_speed":200,"cookie_lifetime":null},"TBMegaMenu":{"TBElementsCounter":{"column":29},"theme":"earthdata"},"colorbox":{"opacity":"0.85","current":"{current} of {total}","previous":"\u00ab Prev","next":"Next \u00bb","close":"Close","maxWidth":"98%","maxHeight":"98%","fixed":true,"mobiledetect":false,"mobiledevicewidth":"480px"},"user":{"uid":0,"permissionsHash":"9f96380f838406ed8b8f43f34118025525e1eacaed9bcd1327470113de0d27cb"}}</script>
# <script src="/s3fs-public/js/js_OjTLiimmGzO8fQT0OdX2VuzljtqLW1C6POMpz9y3EBU.js?VersionId=Smji5H4cWx8JOXNcGtRKtch7l3U8o0mG"></script>
# <script async="" src="//www.googletagmanager.com/gtag/js?id=GTM-WNP7MLF"></script>
# <script async="" src="//script.crazyegg.com/pages/scripts/0013/2090.js"></script>
# <script id="_fed_an_ua_tag" src="//dap.digitalgov.gov/Universal-Federated-Analytics-Min.js?agency=NASA&amp;subagency=GSFC&amp;dclink=true"></script>
# <meta content="613" name="orgcode"/>
# <meta content="Kevin Murphy" name="rno"/>
# <meta content="Kevin Ward" name="content-owner"/>
# <meta content="Goran Halusa" name="webmaster"/>
# <meta content="The Earth Observing System Data and Information System
#        is a key core capability in NASA’s Earth Science Data Systems Program. It provides end-to-end
#        capabilities for managing NASA’s Earth science data from various sources—satellites, aircraft,
#        field measurements, and various other programs." name="description"/>
# </head>

# %%
import requests
from bs4 import BeautifulSoup

# Make a request
page = requests.get(
    "https://www.earthdata.nasa.gov/engage/open-data-services-and-software/api")
soup = BeautifulSoup(page.content, 'html.parser')

# Extract first <h1>(...)</h1> text
first_h1 = soup.select('h1')[0].text

# %%
import requests
from bs4 import BeautifulSoup
# Make a request
page = requests.get(
    "https://www.earthdata.nasa.gov/engage/open-data-services-and-software/api")
soup = BeautifulSoup(page.content, 'html.parser')

# Create all_h1_tags as empty list
all_h1_tags = []

# Set all_h1_tags to all h1 tags of the soup
for element in soup.select('h1'):
    all_h1_tags.append(element.text)

# Create seventh_p_text and set it to 7th p element text of the page
seventh_p_text = soup.select('p')[6].text

print(all_h1_tags, seventh_p_text)
# Out:
# ['Earthdata Developer Portal'] The cryosphere encompasses the frozen parts of Earth, including glaciers and ice sheets, sea ice, and any other frozen body of water. The cryosphere plays a critical role in regulating climate and sea levels.

# %%
info = {
   "title": 'Asus AsusPro Adv...   '.strip(),
   "review": '2 reviews\n\n\n'.strip()
}

# %%
import requests
from bs4 import BeautifulSoup
# Make a request
page = requests.get(
    "https://www.earthdata.nasa.gov/engage/open-data-services-and-software/api")
soup = BeautifulSoup(page.content, 'html.parser')

# Create top_items as empty list
top_items = []

# Extract and store in top_items according to instructions on the left
products = soup.select('div.thumbnail')
for elem in products:
    title = elem.select('h4 > a.title')[0].text
    review_label = elem.select('div.ratings')[0].text
    info = {
        "title": title.strip(),
        "review": review_label.strip()
    }
    top_items.append(info)

print(top_items)
# Out:
# []

# %%
import requests
from bs4 import BeautifulSoup
# Make a request
page = requests.get(
    "https://www.earthdata.nasa.gov/engage/open-data-services-and-software/api")
soup = BeautifulSoup(page.content, 'html.parser')

# Create top_items as empty list
image_data = []

# Extract and store in top_items according to instructions on the left
images = soup.select('img')
for image in images:
    src = image.get('src')
    alt = image.get('alt')
    image_data.append({"src": src, "alt": alt})

print(image_data)
# Out:
# [{'src': '/sites/default/files/earthdata-oaos-logo.png', 'alt': 'Earthdata logo'}, {'src': '/sites/default/files/earthdata-oaos-logo-hover.png', 'alt': 'Earthdata logo'}, {'src': '/s3fs-public/2021-12/topics-nav-image.png?VersionId=QMAaSpRww7HoOsbxodDTFP9MPWmaR.3t', 'alt': 'Topics navigation graphic - a globe and magnifying glass.'}, {'src': '/sites/default/files/2021-08/atmosphere-icon.png', 'alt': 'Atmosphere icon'}, {'src': '/sites/default/files/2021-08/biosphere-icon.png', 'alt': 'Biosphere'}, {'src': '/sites/default/files/2021-08/cryosphere-icon.png', 'alt': 'Cryosphere icon'}, {'src': '/sites/default/files/2021-08/human-dimensions-icon.png', 'alt': 'Human Dimensions icon'}, {'src': '/sites/default/files/2021-08/land-surface-icon.png', 'alt': 'Land Surface icon'}, {'src': '/sites/default/files/2021-08/ocean-icon.png', 'alt': 'Oceans icon'}, {'src': '/sites/default/files/2021-08/solid-earth-icon.png', 'alt': 'Solid Earth icon'}, {'src': '/sites/default/files/2021-08/sun-earth-interactions-icon.png', 'alt': 'Sun-Earth Interactions icon'}, {'src': '/sites/default/files/2021-08/terrestrial-hydrosphere-icon.png', 'alt': 'Terrestrial Hydrosphere icon'}, {'src': '/s3fs-public/earthdata-oaos-logo.png?VersionId=h5vKcBx45miaimU2tElXhOWilgws_kIs', 'alt': 'Home'}, {'src': '/s3fs-public/2021-12/learn-nav-image.png?VersionId=aWb2AOrq0TWA1S.blcAnbck4BKhZxDMR', 'alt': 'Learn navigation graphic - an illustration of 3 students.'}, {'src': '/s3fs-public/2021-12/engage-nav-image.png?VersionId=Iymn0s3WOLjfRuzdBAm8b14rgIvEoAxK', 'alt': 'Engage navigation graphic - an illustration of multiple data users/consumers.'}, {'src': '/s3fs-public/2021-12/about-nav-image.png?VersionId=KGfJpEh4f.srWVm42vPTk.ds3e_6SpAs', 'alt': 'About navigation graphic - an illustration of a satellite.'}, {'src': '/sites/default/files/search.png', 'alt': 'search'}, {'src': '/sites/default/files/search.png', 'alt': 'search icon'}, {'src': '/sites/default/files/icons/facebook-icon.png', 'alt': 'fb_icon'}, {'src': '/sites/default/files/icons/twitter-icon.png', 'alt': 'twitter_icon'}, {'src': '/sites/default/files/icons/youtube-icon.png', 'alt': 'yt_icon'}]

# %%
info = {
   "href": "<link here>",
   "text": "<link text here>"
}

# %%
import requests
from bs4 import BeautifulSoup
# Make a request
page = requests.get(
    "https://www.earthdata.nasa.gov/engage/open-data-services-and-software/api")
soup = BeautifulSoup(page.content, 'html.parser')

# Create top_items as empty list
all_links = []

# Extract and store in top_items according to instructions on the left
links = soup.select('a')
for ahref in links:
    text = ahref.text
    text = text.strip() if text is not None else ''

    href = ahref.get('href')
    href = href.strip() if href is not None else ''
    all_links.append({"href": href, "text": text})

print(all_links)
# Out:
# [{'href': '#main-content', 'text': 'Skip to main content'}, {'href': '/', 'text': ''}, {'href': '/learn/get-started', 'text': 'Get Started'}, {'href': '/learn/find-data', 'text': 'Find Data'}, {'href': '/learn/use-data', 'text': 'Use Data'}, {'href': 'https://search.earthdata.nasa.gov/', 'text': 'Earthdata Search'}, {'href': '/use-data/tools', 'text': 'Data Tools'}, {'href': '/learn/data-recipes', 'text': 'Data Recipes'}, {'href': '/worldview', 'text': 'Worldview'}, {'href': '/worldview/worldview-image-archive', 'text': 'Worldview Image of the Week'}, {'href': '/worldview/worldview-snapshots', 'text': 'Worldview Snapshots'}, {'href': '/eosdis/science-system-description/eosdis-components/gibs', 'text': 'Global Imagery Browse Services (GIBS)'}, {'href': '/eosdis/science-system-description/eosdis-components/cmr', 'text': 'Common Metadata Repository (CMR)'}, {'href': '/learn/find-data/near-real-time', 'text': 'Land, Atmosphere Near Real-Time Data (LANCE)'}, {'href': '/find-data/near-real-time/firms', 'text': 'Fire Information for Resource Management System (FIRMS)'}, {'href': '/learn/find-data/near-real-time/firms/active-fire-data', 'text': 'Active Fire Data'}, {'href': 'https://firms.modaps.eosdis.nasa.gov/alerts/', 'text': 'Fire Email Alerts'}, {'href': 'https://firms.modaps.eosdis.nasa.gov/map/', 'text': 'Fire Map (Global)'}, {'href': 'https://firms.modaps.eosdis.nasa.gov/usfs/map', 'text': 'Fire Map (US/Canada)'}, {'href': '/topics', 'text': 'Topics'}, {'href': 'https://www.earthdata.nasa.gov/s3fs-public/2021-12/topics-nav-image.png?VersionId=QMAaSpRww7HoOsbxodDTFP9MPWmaR.3t', 'text': ''}, {'href': '/topics/atmosphere', 'text': 'Atmosphere'}, {'href': '/topics/biosphere', 'text': 'Biosphere'}, {'href': '/topics/cryosphere', 'text': 'Cryosphere'}, {'href': '/topics/human-dimensions', 'text': 'Human Dimensions'}, {'href': '/topics/land-surface', 'text': 'Land Surface'}, {'href': '/topics/ocean', 'text': 'Ocean'}, {'href': '/topics/solid-earth', 'text': 'Solid Earth'}, {'href': '/topics/sun-earth-interactions', 'text': 'Sun-Earth Interactions'}, {'href': '/topics/terrestrial-hydrosphere', 'text': 'Terrestrial Hydrosphere'}, {'href': '/', 'text': ''}, {'href': '/learn', 'text': 'Learn'}, {'href': 'https://www.earthdata.nasa.gov/s3fs-public/2021-12/learn-nav-image.png?VersionId=aWb2AOrq0TWA1S.blcAnbck4BKhZxDMR', 'text': ''}, {'href': '/learn/get-started', 'text': 'Get Started'}, {'href': '/learn/backgrounders', 'text': 'Backgrounders'}, {'href': '/learn/pathfinders', 'text': 'Data Pathfinders'}, {'href': '/learn/toolkits', 'text': 'Data Toolkits'}, {'href': '/learn/webinars-and-tutorials', 'text': 'Webinars and Tutorials'}, {'href': '/learn/articles', 'text': 'Articles'}, {'href': '/learn/data-chat', 'text': 'Data Chats'}, {'href': '/learn/data-user-profiles', 'text': 'Data User Profiles'}, {'href': '/engage', 'text': 'Engage'}, {'href': 'https://www.earthdata.nasa.gov/s3fs-public/2021-12/engage-nav-image.png?VersionId=Iymn0s3WOLjfRuzdBAm8b14rgIvEoAxK', 'text': ''}, {'href': '/engage/data-management-guidance', 'text': 'Data Management Guidance'}, {'href': '/engage/open-data-services-and-software', 'text': 'Open Data, Services, and Software Policies'}, {'href': '/engage/open-data-services-and-software/esds-open-source-policy', 'text': 'Open Source Software Policy'}, {'href': '/engage/open-data-services-and-software/api', 'text': 'Application Programming Interfaces (APIs)'}, {'href': '/engage/ecc', 'text': 'Earthdata Code Collaborative (ECC)'}, {'href': '/engage/standards', 'text': 'Standards'}, {'href': '/esdis/eso/standards-and-references', 'text': 'Data Standards and Requirements'}, {'href': '/use-data/data-use-policy', 'text': 'Data Use Policy'}, {'href': '/use-data/data-citations-acknowledgements', 'text': 'Data Citations and Acknowledgements'}, {'href': '/engage/new-missions', 'text': 'Adding New Data to EOSDIS'}, {'href': '/engage/esds-public-private-partnerships', 'text': 'Public & Private Partnerships'}, {'href': '/engage/me ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import datetime

# Define the URL of the webpage you want to scrape
url = "https://www.earthdata.nasa.gov/engage/open-data-services-and-software/api"

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content of the page using BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find all anchor (a) tags with href attributes
    links = soup.find_all('a', href=True)
    
    # Create a list to store the links
    link_list = []
    
    # Loop through the links and add their href attributes to the list
    for link in links:
        link_href = link['href']
        link_list.append(link_href)
    
    # Create a DataFrame from the list of links
    df = pd.DataFrame({'Link': link_list})
    
    # Define metadata
    metadata = {
        'Source URL': url,
        'Scraped Date': datetime.date.today().isoformat()
    }
    
    # Add metadata as additional columns
    for key, value in metadata.items():
        df[key] = value
    
    # Print the first few rows of the DataFrame with metadata
    print(df.head())
else:
    print("Failed to retrieve the webpage")
# Out:
#                  Link                                         Source URL  \
# 0       #main-content  https://www.earthdata.nasa.gov/engage/open-dat...
# 1                   /  https://www.earthdata.nasa.gov/engage/open-dat...
# 2  /learn/get-started  https://www.earthdata.nasa.gov/engage/open-dat...
# 3    /learn/find-data  https://www.earthdata.nasa.gov/engage/open-dat...
# 4     /learn/use-data  https://www.earthdata.nasa.gov/engage/open-dat...
#
#   Scraped Date
# 0   2023-09-04
# 1   2023-09-04
# 2   2023-09-04
# 3   2023-09-04
# 4   2023-09-04

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a DataFrame 'df' with the scraped data
link_counts = df['Link'].value_counts()

# Create a bar chart
plt.figure(figsize=(12, 6))
link_counts.head(10).plot(kind='bar')
plt.title('Top 10 Most Common Links')
plt.xlabel('Link')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a DataFrame 'df' with the scraped data
link_counts = df['Link'].value_counts()

# Create a bar chart
plt.figure(figsize=(12, 6))
link_counts.head(10).plot(kind='hist')
plt.title('Top 10 Most Common Links')
plt.xlabel('Link')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# %%
import requests
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt

# Define the URL of the webpage you want to scrape
url = "https://www.earthdata.nasa.gov/engage/open-data-services-and-software/api"

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content of the page using BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find all anchor (a) tags with href attributes
    links = soup.find_all('a', href=True)
    
    # Create a list to store the lengths of link text
    link_text_lengths = [len(link.text) for link in links]
    
    # Create a histogram of link text lengths
    plt.hist(link_text_lengths, bins=20, edgecolor='k')
    plt.title('Histogram of Link Text Lengths')
    plt.xlabel('Text Length')
    plt.ylabel('Frequency')
    plt.show()
else:
    print("Failed to retrieve the webpage")

# %%
import requests
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt

# Define the URL of the webpage you want to scrape
url = "https://www.earthdata.nasa.gov/engage/open-data-services-and-software/api"

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content of the page using BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find all anchor (a) tags with href attributes
    links = soup.find_all('a', href=True)
    
    # Create a list to store link categories (hypothetical)
    # You can modify this to categorize links based on your criteria
    link_categories = ['Category A', 'Category B', 'Category C']
    
    # Create a dictionary to store the count of links in each category
    category_counts = {category: 0 for category in link_categories}
    
    # Simulate categorizing links (you should replace this with your logic)
    for link in links:
        # Example: Categorize links based on the presence of specific keywords
        if 'keyword1' in link['href']:
            category_counts['Category A'] += 1
        elif 'keyword2' in link['href']:
            category_counts['Category B'] += 1
        else:
            category_counts['Category C'] += 1
    
    # Prepare data for the pie chart
    categories = list(category_counts.keys())
    counts = list(category_counts.values())
    
    # Create a pie chart
    plt.figure(figsize=(8, 8))
    plt.pie(counts, labels=categories, autopct='%1.1f%%', startangle=140)
    plt.title('Distribution of Link Categories')
    plt.show()
else:
    print("Failed to retrieve the webpage")

# %%
import requests
from bs4 import BeautifulSoup
import seaborn as sns
import matplotlib.pyplot as plt

# Define the URL of the webpage you want to scrape
url = "https://www.earthdata.nasa.gov/engage/open-data-services-and-software/api"

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content of the page using BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find all anchor (a) tags with href attributes
    links = soup.find_all('a', href=True)
    
    # Create a list to store the lengths of link text
    link_text_lengths = [len(link.text) for link in links]
    
    # Create a distribution plot (distplot)
    sns.set_style("whitegrid")
    plt.figure(figsize=(8, 6))
    sns.distplot(link_text_lengths, kde=False, bins=20)
    plt.title('Distribution of Link Text Lengths')
    plt.xlabel('Text Length')
    plt.ylabel('Frequency')
    plt.show()
else:
    print("Failed to retrieve the webpage")
# Out:
# C:\Users\yashr\AppData\Local\Temp\ipykernel_15228\2460364207.py:26: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(link_text_lengths, kde=False, bins=20)

# %%
import requests
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import pandas as pd

# Define the URL of the webpage you want to scrape
url = "https://www.earthdata.nasa.gov/engage/open-data-services-and-software/api"

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content of the page using BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find all anchor (a) tags with href attributes
    links = soup.find_all('a', href=True)
    
    # Example: Create a DataFrame with hypothetical numerical data
    # Replace this with your actual data
    data = {
        'Date': pd.date_range(start='2023-01-01', periods=len(links)),  # Example dates
        'Value': range(len(links))  # Example numerical values
    }
    df = pd.DataFrame(data)
    
    # Create a line chart
    plt.figure(figsize=(10, 6))
    plt.plot(df['Date'], df['Value'], marker='o', linestyle='-')
    plt.title('Line Chart of Hypothetical Data')
    plt.xlabel('Date')
    plt.ylabel('Value')
    plt.grid(True)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
else:
    print("Failed to retrieve the webpage")

# %%
import requests
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import pandas as pd
import random

# Define the URL of the webpage you want to scrape
url = "https://www.earthdata.nasa.gov/engage/open-data-services-and-software/api"

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content of the page using BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find all anchor (a) tags with href attributes
    links = soup.find_all('a', href=True)
    
    # Example: Create a DataFrame with random numerical data
    # Replace this with your actual data
    data = {
        'X_Value': [random.uniform(0, 10) for _ in links],  # Example X values
        'Y_Value': [random.uniform(0, 10) for _ in links]   # Example Y values
    }
    df = pd.DataFrame(data)
    
    # Create a scatter plot
    plt.figure(figsize=(8, 6))
    plt.scatter(df['X_Value'], df['Y_Value'], s=50, alpha=0.5)
    plt.title('Scatter Plot of Hypothetical Data')
    plt.xlabel('X Value')
    plt.ylabel('Y Value')
    plt.grid(True)
    plt.tight_layout()
    plt.show()
else:
    print("Failed to retrieve the webpage")

# %%
import requests
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import pandas as pd
import random

# Define the URL of the webpage you want to scrape
url = "https://www.earthdata.nasa.gov/engage/open-data-services-and-software/api"

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content of the page using BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find all anchor (a) tags with href attributes
    links = soup.find_all('a', href=True)
    
    # Example: Create a DataFrame with random numerical data
    # Replace this with your actual data
    data = {
        'Value': [random.uniform(0, 10) for _ in links]  # Example numeric values
    }
    df = pd.DataFrame(data)
    
    # Create a box plot
    plt.figure(figsize=(6, 8))
    plt.boxplot(df['Value'], vert=False, widths=0.7)
    plt.title('Box Plot of Hypothetical Data')
    plt.xlabel('Value')
    plt.grid(True)
    plt.tight_layout()
    plt.show()
else:
    print("Failed to retrieve the webpage")
